# %% [markdown]
# IA & Data science (LU3IN0226) -- 2021-2022
# --------
# *&copy; Equipe pédagogique: Vincent Guigue, Christophe Marsala, Olivier Schwander.*

# %% [markdown]
# <font size="+1" color="RED"><b>[Q]</b></font> <font size="+1"><b>Indiquer dans la boîte ci-dessous vos noms et prénoms :</b></font>

# %% [markdown]
#      Binome 01 : Samy Mouloud NEHLIL 21113646

# %% [markdown]
# <b>Ce projet peut être fait en binôme (et c'est fortement conseillé) ou tout seul.</b>
# Le nom de chaque membre du binôme doit être indiqué, et un seul rendu sur un des deux comptes Moodle doit être fait.
#
# <b>Les groupes de plus de 2 personnes ne sont pas autorisés.</b>

# %% [markdown]
# <font color="RED" size="+1"><b>[Q]</b></font> **Renommer ce fichier ipython**
#
# Tout en haut de cette page, cliquer sur <tt>projet-2</tt> et rajouter à la suite de <tt>projet-2</tt> les noms des membres du binômes séparés par un tiret.
#
# <font color="RED" size="+1">IMPORTANT: soumission de votre fichier final</font>
#
# **Nom à donner au notebook** : *projet-2-Nom1_Nom2.ipynb*
# - *Nom1* et *Nom2* : noms des membres du binôme
#
# **Le compte-rendu doit être rendu sur la page Moodle.**

# %% [markdown]
# # Projet 2 - avril-mai 2022
#
#
# <font size="+1" color="RED"><b>Date de rendu : lundi 9 mai, 19h au plus tard</b></font>
#
# (<b>attention! le site Moodle ferme à 19h pile !</b> prévoyez de vous y connecter au moins 15mn avant la fermeture...)
#
#
# Vous devez compléter ce notebook en rajoutant vos expérimentations avec vos algorithmes d'apprentissage sur les données Agribalise qui sont des données ouvertes dont la documentation peut être consultée ici : https://doc.agribalyse.fr/documentation/acces-donnees
#
# Très important : les fichiers de données doivent être placés de façon à respecter la structure de fichiers suivante :
#
#           --iads/
#               -- Classifiers.py
#               -- etc.
#           -- projet/
#               -- ce_notebook.ipynb
#               -- Donnees_Agribalyse/
#                   -- detail_ingredient.csv
#                   -- detail_etape.csv
#                   -- synthese.csv
#
# Dans le notebook, le chargement des fichiers de données considèrera donc cette arborescence.
#
# ## Travail à faire
#
# Appliquer les algorithmes d'apprentissage vus tout au long du semestre sur les données afin de mettre en évidence des résultats intéressants.
# Deux problèmes, au moins, doivent être traités:
# - un problème d'apprentissage supervisé
# - un problème d'apprentissage non supervisé
#
#
# ## Travail à rendre
# Ce qui doit être remis avant la date limite : un fichier archive (`.tar`, `.tgz`, ou `.zip` uniquement) contenant:
# - ce notebook complété. Il doit pouvoir être exécuté sans autre apport (pensez à vous en assurer avant de le rendre).
# - votre librairie iads sous la forme d'une archive du répertoire iads/
# - un fichier PDF dont le nom est de la forme: *projet-1-Nom1_Nom2.pdf* qui correspond à un poster décrivant l'ensemble des expérimentations menées et les résultats obtenus.
#
#
# <b>IMPORTANT</b>: Les fichiers de données ne doivent pas être inclus dans votre archive !
#
# ## Soutenance des projets
# La soutenance sera organisée après la semaine d'examens de mai entre le 17 et le 25 mai (la date sera précisé sur le forum du Moodle).
#
# La <b>soutenance est obligatoire</b> : tout projet pour lequel une soutenance n'a pas eu lieu sera noté $0$.
#
# Modalités de la soutenance:
# - durée de la soutenance : 10 mn pour un binôme, 7 mn pour un monôme ;
# - elle a lieu devant un ordinateur avec le notebook et le poster comme support ;
#     - elle commence par une rapide présentation des expérimentations réalisées et résultats obtenus (max. 4 à 5mns)
#     - puis elle se poursuit par des questions posées individuellement aux membres du binômes sur les expériences ou le code python réalisé.
# - la note de soutenance est individuelle pour chaque membre d'un binôme.

# %%
# Importation des librairies standards:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
# %matplotlib inline
import seaborn as sns
import math
import time
import graphviz as gv
import random

# Importation de votre librairie iads:
# La ligne suivante permet de préciser le chemin d'accès à la librairie iads
import sys
sys.path.append('../')   # iads doit être dans le répertoire frère du répertoire courant !

# Importation de la librairie iads
import iads as iads

# importation de Classifiers
from iads import Classifiers as cl

# importation de utils
from iads import utils as ut

# importation de Clustering
from iads import Clustering as clust

# commande TRES utile pour recharger automatiquement le code que vous modifiez dans les modules
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
patients_df = pd.read_json('Donnees_Agribalyse/Agribalyse.json')
patients_df.head()
# Out:
#   nom_francais                          LCI_name  ciqual_AGB  ciqual_code  \
# 0       Pastis   Pastis (anise-flavoured spirit)        1000         1000
# 1   Eau de vie  Clear fruit brandy or eau-de-vie        1001         1001
# 2          Gin                               Gin        1002         1002
# 3      Liqueur                           Liqueur        1003         1003
# 4         Rhum                               Rum        1004         1004
#
#      groupe          sous_groupe                  saison  avion  \
# 0  boissons  boisson alcoolisées  mix de consommation FR  False
# 1  boissons  boisson alcoolisées  mix de consommation FR  False
# 2  boissons  boisson alcoolisées  mix de consommation FR  False
# 3  boissons  boisson alcoolisées  mix de consommation FR  False
# 4  boissons  boisson alcoolisées  mix de consommation FR  False
#
#      materiau_emballage          Livraison                     Preparation  \
# 0                 Verre  Ambiant (moyenne)  Réfrigéré chez le consommateur
# 1                 Verre  Ambiant (moyenne)              Pas de préparation
# 2                 Verre  Ambiant (moyenne)  Réfrigéré chez le consommateur
# 3  Déjà emballé - Verre  Ambiant (moyenne)  Réfrigéré chez le consommateur
# 4                 Verre  Ambiant (moyenne)  Réfrigéré chez le consommateur
#
#                                                  DQR  \
# 0  {'overall': '3.29', 'P': '2.49', 'TiR': '2.73'...
# 1  {'overall': '3.3', 'P': '2.48', 'TiR': '2.72',...
# 2  {'overall': '3.29', 'P': '2.49', 'TiR': '2.73'...
# 3  {'overall': '3.68', 'P': '2.54', 'TiR': '3.69'...
# 4  {'overall': '3.29', 'P': '2.49', 'TiR': '2.73'...
#
#                               impact_environnemental
# 0  {'Score unique EF': {'synthese': 0.12303632999...
# 1  {'Score unique EF': {'synthese': 0.12053738, '...
# 2  {'Score unique EF': {'synthese': 0.12296672000...
# 3  {'Score unique EF': {'synthese': 0.25146514999...
# 4  {'Score unique EF': {'synthese': 0.12296672000...

# %% [markdown]
# # Approche de résolution du projet

# %% [markdown]
# <div class="alert alert-info" role="alert">
#  Afin de bien mener ce projet, nous avons décidé de définir dés le début une méthode de travail (approche) nous permettant à la fois de répondre au cahier des charges et respecter les deadlines, pour cela nous avons choisi l'approche PPDAC :
#     <ul>
#         <li>Problem : Bien cadrer notre problème</li>
#         <li>Plan : définir un schéma experimental afin de résoudre le problème</li>
#         <li>Data : Explorer les données</li>
#         <li>Analysis : faire des manipulations sur les données, appliquer des modèles d'apprentissage  et évaluer les performances</li>
#         <li>Conclusion : Conclure par rapport aux résultats des étapes précédentes</li>
#     </ul></div>

# %% [markdown]
# # Schéma expérimental

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <ul>
#     <li><b>Exploration des données :</b> prise en main des données, comprendre les attributs et les associations qui peuvent exister entre les tables de notre base de données.</li>
#     <li><b>Prétraitement des données :</b> Appliquer des transformations sur les données pour les rendre plus significatifs, et assurer la cohérence entre les différentes valeurs possibles par attribut.</li>
#     <li><b>Entrainement des modèles :</b> Selection de la base d'apprentissage pour chaque problème identifié, et résoudre ce problème avec les différents algorithmes doint on dispose.</li>
#     <li><b>Evaluation des modèles :</b> Choisir une méthode d'évaluation à appliquer sur les modèles.</li>
#     <li><b>Synthèse et Justification des résultats obtenus</b>.</li>
# </ul>
# </div>

# %% [markdown]
# ***

# %% [markdown]
# # 1 Table synthèse

# %% [markdown]
# ## 1.1 Exploration des données

# %% [markdown]
# <div class="alert alert-info" role="alert">
# En premier lieu, nous allons dans la découverte et la prise en main des données, pour cela nous allons effectuer des affichages, visualisations, analyse statistiques (dispersion, médiane ..) que nous jugeons pertinentes afin de mieux comprendre les données.
# </div>

# %%
# Chargement des données
data_synthese = pd.read_csv("Donnees_Agribalyse/synthese.csv")
data_synthese.columns
print("Taille du dataset: ",data_synthese.shape)
# Out:
# Taille du dataset:  (2479, 27)

# %%
# Conversion vers numpy array
arr = np.array(data_synthese)
a = np.unique(arr[:,4])
a
# Out:
# array(['Abricot au sirop léger, appertisé, non égoutté',
#        'Abricot au sirop léger, appertisé, égoutté',
#        'Abricot au sirop, appertisé, non égoutté', ...,
#        'Épinard, surgelé, cuit', 'Épinards à la crème', 'Époisses'],
#       dtype=object)

# %%
#get an overview of the data
data_synthese.head()
# Out:
#   Code AGB  Code CIQUAL                             Groupe d'aliment  \
# 0    13712        13712  fruits, légumes, légumineuses et oléagineux
# 1    13713        13713  fruits, légumes, légumineuses et oléagineux
# 2    13714        13714  fruits, légumes, légumineuses et oléagineux
# 3    13715        13715  fruits, légumes, légumineuses et oléagineux
# 4    13000        13000  fruits, légumes, légumineuses et oléagineux
#
#   Sous-groupe d'aliment                      Nom du Produit en Français  \
# 0                fruits      Abricot au sirop léger, appertisé, égoutté
# 1                fruits  Abricot au sirop léger, appertisé, non égoutté
# 2                fruits            Abricot au sirop, appertisé, égoutté
# 3                fruits        Abricot au sirop, appertisé, non égoutté
# 4                fruits                         Abricot, dénoyauté, cru
#
#                                       LCI Name            Saisonnalité  \
# 0      Apricot, canned in light syrup, drained  mix de consommation FR
# 1  Apricot, canned in light syrup, not drained  mix de consommation FR
# 2           Apricot, in syrup, canned, drained  mix de consommation FR
# 3       Apricot, in syrup, canned, not drained  mix de consommation FR
# 4                         Apricot, pitted, raw  mix de consommation FR
#
#    Transport par avion (1 : par avion)          Livraison  \
# 0                                    0  Ambiant (moyenne)
# 1                                    0  Ambiant (moyenne)
# 2                                    0  Ambiant (moyenne)
# 3                                    0  Ambiant (moyenne)
# 4                                    0  Ambiant (moyenne)
#
#   Matériau d'emballage  ... Particules (E-06 disease inc./kg de produit)  \
# 0                Acier  ...                                     0.096413
# 1                Acier  ...                                     0.059314
# 2                Acier  ...                                     0.096413
# 3                Acier  ...                                     0.059314
# 4                 LPDE  ...                                     0.061462
#
#    Acidification terrestre et eaux douces (mol H+ eq/kg de produit)  \
# 0                                           0.009301
# 1                                           0.005726
# 2                                           0.009301
# 3                                           0.005726
# 4                                           0.007254
#
#    Eutrophisation terreste (mol N eq/kg de produit)  \
# 0                                          0.031766
# 1                                          0.019499
# 2                                          0.031766
# 3                                          0.019499
# 4                                          0.025954
#
#    Eutrophisation eaux douces (E-03 kg P eq/kg de produit)  \
# 0                                           0.410555
# 1                                           0.235366
# 2                                           0.410555
# 3                                           0.235366
# 4                                           0.204244
#
#    Eutrophisation marine (E-03 kg N eq/kg de produit)  \
# 0                                           1.502775
# 1                                           0.797791
# 2                                           1.502775
# 3                                           0.797791
# 4                                           0.943669
#
#    Utilisation du sol (Pt/kg de produit)  \
# 0                              44.823181
# 1                              27.901738
# 2                              44.823181
# 3                              27.901738
# 4                              43.838644
#
#    Écotoxicité pour écosystèmes aquatiques d'eau douce (CTUe/kg de produit)  \
# 0                                          62.195218
# 1                                          36.285914
# 2                                          62.195218
# 3                                          36.285914
# 4                                          41.957928
#
#    Épuisement des ressources eau (m3 depriv./kg de produit)  \
# 0                                           1.630637
# 1                                           1.010960
# 2                                           1.630637
# 3                                           1.010960
# 4                                           1.412878
#
#    Épuisement des ressources énergétiques (MJ/kg de produit)  \
# 0                                          47.237697
# 1                                          29.397697
# 2                                          47.237697
# 3                                          29.397697
# 4                                          17.123820
#
#    Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit)
# 0                                           2.938064
# 1                                           1.823726
# 2                                           2.938064
# 3                                           1.823726
# 4                                           2.173328
#
# [5 rows x 27 columns]

# %%
data_synthese.tail()
# Out:
#      Code AGB  Code CIQUAL           Groupe d'aliment  \
# 2474    19592        19592  lait et produits laitiers
# 2475    19593        19593  lait et produits laitiers
# 2476    19594        19594  lait et produits laitiers
# 2477    19598        19598  lait et produits laitiers
# 2478    19599        19599  lait et produits laitiers
#
#                      Sous-groupe d'aliment  \
# 2474  produits laitiers frais et assimilés
# 2475  produits laitiers frais et assimilés
# 2476  produits laitiers frais et assimilés
# 2477  produits laitiers frais et assimilés
# 2478  produits laitiers frais et assimilés
#
#                              Nom du Produit en Français  \
# 2474  Yaourt, lait fermenté ou spécialité laitière, ...
# 2475  Yaourt, lait fermenté ou spécialité laitière, ...
# 2476  Yaourt, lait fermenté ou spécialité laitière, ...
# 2477  Yaourt, lait fermenté ou spécialité laitière, ...
# 2478  Yaourt, lait fermenté ou spécialité laitière, ...
#
#                                                LCI Name  \
# 2474  Yogurt, fermented milk or dairy specialty, wit...
# 2475   Yogurt, fermented milk or dairy specialty, plain
# 2476  Yogurt, fermented milk or dairy specialty, pla...
# 2477  Yogurt, fermented milk or dairy specialty, pla...
# 2478  Yogurt, fermented milk or dairy specialty, pla...
#
#                 Saisonnalité  Transport par avion (1 : par avion) Livraison  \
#                 Saisonnalité  Transport par avion (1 : par avion)  \
# 341   mix de consommation FR                                    0
# 1227  mix de consommation FR                                    0
# 1889  mix de consommation FR                                    0
# 1871  mix de consommation FR                                    0
# 1717  mix de consommation FR                                    0
#
#               Livraison Matériau d'emballage  ...  \
# 341   Ambiant (moyenne)      Pas d'emballage  ...
# 1227              Glacé                 HPDE  ...
# 1889              Glacé                   PP  ...
# 1871              Glacé   Déjà emballé - PET  ...
# 1717            Congelé                   PP  ...
#
#      Particules (E-06 disease inc./kg de produit)  \
# 341                                      0.033102
# 1227                                     0.105173
# 1889                                     0.525790
# 1871                                     1.704544
# 1717                                     0.043458
#
#       Acidification terrestre et eaux douces (mol H+ eq/kg de produit)  \
# 341                                            0.004065
# 1227                                           0.014782
# 1889                                           0.073611
# 1871                                           0.241036
# 1717                                           0.005416
#
#       Eutrophisation terreste (mol N eq/kg de produit)  \
# 341                                           0.014009
# 1227                                          0.061972
# 1889                                          0.314925
# 1871                                          1.038402
# 1717                                          0.018704
#
#       Eutrophisation eaux douces (E-03 kg P eq/kg de produit)  \
# 341                                            0.119384
# 1227                                           0.156170
# 1889                                           0.712695
# 1871                                           2.153420
# 1717                                           0.231774
#
#       Eutrophisation marine (E-03 kg N eq/kg de produit)  \
# 341                                            4.955335
# 1227                                           4.227887
# 1889                                          18.433288
# 1871                                          54.992296
# 1717                                           5.582116
#
#       Utilisation du sol (Pt/kg de produit)  \
# 341                                8.830993
# 1227                              68.507600
# 1889                             230.861310
# 1871                             745.243440
# 1717                              71.669232
#
#       Écotoxicité pour écosystèmes aquatiques d'eau douce (CTUe/kg de produit)  \
# 341                                           17.059999
# 1227                                          21.017726
# 1889                                          98.498387
# 1871                                         293.306870
# 1717                                          33.795862
#
#       Épuisement des ressources eau (m3 depriv./kg de produit)  \
# 341                                            0.997938
# 1227                                           0.486548
# 1889                                           3.839857
# 1871                                          10.312270
# 1717                                           2.749493
#
#       Épuisement des ressources énergétiques (MJ/kg de produit)  \
# 341                                           12.319274
# 1227                                          14.804330
# 1889                                          74.111823
# 1871                                         180.315370
# 1717                                          29.613305
#
#       Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit)
# 341                                            2.412127
# 1227                                           1.569584
# 1889                                           5.925879
# 1871                                          14.949001
# 1717                                           2.806599
#
# [5 rows x 27 columns]

# %%
# Vue globale sur les données
data_synthese.describe()
# Out:
#         Code CIQUAL  Transport par avion (1 : par avion)  \
# count   2479.000000                          2479.000000
# mean   22446.076240                             0.000807
# std    14034.948243                             0.028398
# min     1000.000000                             0.000000
# 25%    12759.500000                             0.000000
# 50%    20511.000000                             0.000000
# 75%    26105.000000                             0.000000
# max    96778.000000                             1.000000
#
#        DQR - Note de qualité de la donnée (1 excellente ; 5 très faible)  \
# count                                        2479.000000
# mean                                            2.810097
# std                                             0.542470
# min                                             1.600000
# 25%                                             2.430000
# 50%                                             2.760000
# 75%                                             3.110000
# max                                             4.870000
#
#        Score unique EF (mPt/kg de produit)  \
# count                          2479.000000
# mean                              0.712264
# std                               0.885750
# min                               0.006130
# 25%                               0.168917
# 50%                               0.394124
# 75%                               0.867402
# max                               6.085768
#
#        Changement climatique (kg CO2 eq/kg de produit)  \
# count                                      2479.000000
# mean                                          5.909752
# std                                           9.138402
# min                                           0.021047
# 25%                                           1.086875
# 50%                                           2.718176
# 75%                                           6.289730
# max                                          62.729303
#
#        Appauvrissement de la couche d'ozone (E-06 kg CVC11 eq/kg de produ
épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit)
# count                                        2479.000000
# mean                                            9.055566
# std                                            19.029156
# min                                             0.108256
# 25%                                             2.686771
# 50%                                             5.041574
# 75%                                            10.082564
# max                                           258.657730

# %%
#identify variable type
data_synthese.dtypes
# Out:
# Code AGB                                                                     object
# Code CIQUAL                                                                   int64
# Groupe d'aliment                                                             object
# Sous-groupe d'aliment                                                        object
# Nom du Produit en Français                                                   object
# LCI Name                                                                     object
# Saisonnalité                                                                 object
# Transport par avion (1 : par avion)                                           int64
# Livraison                                                                    object
# Matériau d'emballage                                                         object
# Préparation                                                                  object
# DQR - Note de qualité de la donnée (1 excellente ; 5 très faible)           float64
# Score unique EF (mPt/kg de produit)                                         float64
# Changement climatique (kg CO2 eq/kg de produit)                             float64
# Appauvrissement de la couche d'ozone (E-06 kg CVC11 eq/kg de produit)       float64
# Rayonnements ionisants (kBq U-235 eq/kg de produit)                         float64
# Formation photochimique d'ozone (E-03 kg NMVOC eq/kg de produit)            float64
# Particules (E-06 disease inc./kg de produit)                                float64
# Acidification terrestre et eaux douces (mol H+ eq/kg de produit)            float64
# Eutrophisation terreste (mol N eq/kg de produit)                            float64
# Eutrophisation eaux douces (E-03 kg P eq/kg de produit)                     float64
# Eutrophisation marine (E-03 kg N eq/kg de produit)                          float64
# Utilisation du sol (Pt/kg de produit)                                       float64
# Écotoxicité pour écosystèmes aquatiques d'eau douce (CTUe/kg de produit)    float64
# Épuisement des ressources eau (m3 depriv./kg de produit)                    float64
# Épuisement des ressources énergétiques (MJ/kg de produit)                   float64
# Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit)            float64
# dtype: object

# %%
data_synthese.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2479 entries, 0 to 2478
# Data columns (total 27 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   Code AGB                                                                  2479 non-null   object
#  1   Code CIQUAL                                                               2479 non-null   int64
#  2   Groupe d'aliment                                                          2479 non-null   object
#  3   Sous-groupe d'aliment                                                     2479 non-null   object
#  4   Nom du Produit en Français                                                2479 non-null   object
#  5   LCI Name                                                                  2479 non-null   object
#  6   Saisonnalité                                                              2479 non-null   object
#  7   Transport par avion (1 : par avion)                                       2479 non-null   int64
#  8   Livraison                                                                 2479 non-null   object
#  9   Matériau d'emballage                                                      2479 non-null   object
#  10  Préparation                                                               2479 non-null   object
#  11  DQR - Note de qualité de la donnée (1 excellente ; 5 très faible)         2479 non-null   float64
#  12  Score unique EF (mPt/kg de produit)                                       2479 non-null   float64
#  13  Changement climatique (kg CO2 eq/kg de produit)                           2479 non-null   float64
#  14  Appauvrissement de la couche d'ozone (E-06 kg CVC11 eq/kg de produit)     2479 non-null   float64
#  15  Rayonnements ionisants (kBq U-235 eq/kg de produit)                       2479 non-null   float64
#  16  Formation photochimique d'ozone (E-03 kg NMVOC eq/kg de produit)          2479 non-null   float64
#  17  Particules (E-06 disease inc./kg de produit)                              2479 non-null   float64
#  18  Acidification terrestre et eaux douces (mol H+ eq/kg de produit)          2479 non-null   float64
#  19  Eutrophisation terreste (mol N eq/kg de produit)                          2479 non-null   float64
#  20  Eutrophisation eaux douces (E-03 kg P eq/kg de produit)                   2479 non-null   float64
#  21  Eutrophisation marine (E-03 kg N eq/kg de produit)                        2479 non-null   float64
#  22  Utilisation du sol (Pt/kg de produit)                                     2479 non-null   float64
#  23  Écotoxicité pour écosystèmes aquatiques d'eau douce (CTUe/kg de produit)  2479 non-null   float64
#  24  Épuisement des ressources eau (m3 depriv./kg de produit)                  2479 non-null   float64
#  25  Épuisement des ressources énergétiques (MJ/kg de produit)                 2479 non-null   float64
#  26  Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit)          2479 non-null   float64
# dtypes: float64(16), int64(2), object(9)
# memory usage: 523.0+ KB

# %%
data_synthese.columns
# Out:
# Index(['Code AGB', 'Code CIQUAL', 'Groupe d'aliment', 'Sous-groupe d'aliment',
#        'Nom du Produit en Français', 'LCI Name', 'Saisonnalité',
#        'Transport par avion (1 : par avion)', 'Livraison',
#        'Matériau d'emballage', 'Préparation',
#        'DQR - Note de qualité de la donnée (1 excellente ; 5 très faible)',
#        'Score unique EF (mPt/kg de produit)',
#        'Changement climatique (kg CO2 eq/kg de produit)',
#        'Appauvrissement de la couche d'ozone (E-06 kg CVC11 eq/kg de produit)',
#        'Rayonnements ionisants (kBq U-235 eq/kg de produit)',
#        'Formation photochimique d'ozone (E-03 kg NMVOC eq/kg de produit)',
#        'Particules (E-06 disease inc./kg de produit)',
#        'Acidification terrestre et eaux douces (mol H+ eq/kg de produit)',
#        'Eutrophisation terreste (mol N eq/kg de produit)',
#        'Eutrophisation eaux douces (E-03 kg P eq/kg de produit)',
#        'Eutrophisation marine (E-03 kg N eq/kg de produit)',
#        'Utilisation du sol (Pt/kg de produit)',
#        'Écotoxicité pour écosystèmes aquatiques d'eau douce (CTUe/kg de produit)',
#        'Épuisement des ressources eau (m3 depriv./kg de produit)',
#        'Épuisement des ressources énergétiques (MJ/kg de produit)',
#        'Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit)'],
#       dtype='object')

# %% [markdown]
# ### Quelques visualisations intéréssantes

# %%
# Bar chart représentats le nombre de groupe d'aliments
plt.figure(figsize=(12, 8))
_ = sns.barplot(x=pd.value_counts(data_synthese["Groupe d'aliment"])[:12], y=pd.value_counts(data_synthese["Groupe d'aliment"])[:12].index)
_ = plt.xlabel("Counts")

# %%
# Affichage de la valeur de la médiane DQR par groupe d'aliment
c = 'DQR - Note de qualité de la donnée (1 excellente ; 5 très faible)'
result = data_synthese.groupby(["Groupe d'aliment"])[c].quantile(0.5)
result.index.values
_ = result.sort_values().plot(kind="barh", figsize=(15, 10), title="Median DQR values by nutrient group")

# %%
# Affichage de la valeur médiane du changement climatique par groupe d'aliment
c = 'Changement climatique (kg CO2 eq/kg de produit)'
result = data_synthese.groupby(["Groupe d'aliment"])[c].quantile(0.5)
_ = result.sort_values().plot(kind="barh", figsize=(15, 10), title="Mediane changement climatique values by nutrient group")

# %%
ut.viewData(data_synthese)

# %%
# Identify missing values of dataframe
data_synthese.isnull()
# Out:
#       Code AGB  Code CIQUAL  Groupe d'aliment  Sous-groupe d'aliment  \
# 0        False        False             False                  False
# 1        False        False             False                  False
# 2        False        False             False                  False
# 3        False        False             False                  False
# 4        False        False             False                  False
# ...        ...          ...               ...                    ...
# 2474     False        False             False                  False
# 2475     False        False             False                  False
# 2476     False        False             False                  False
# 2477     False        False             False                  False
# 2478     False        False             False                  False
#
#       Nom du Produit en Français  LCI Name  Saisonnalité  \
# 0                          False     False         False
# 1                          False     False         False
# 2                          False     False         False
# 3                          False     False         False
# 4                          False     False         False
# ...                          ...       ...           ...
# 2474                       False     False         False
# 2475                       False     False         False
# 2476                       False     False         False
# 2477                       False     False         False
# 2478                       False     False         False
#
#       Transport par avion (1 : par avion)  Livraison  Matériau d'emballage  \
# 0                                   False      False                 False
# 1                                   False      False                 False
# 2                                   False      False                 False
# 3                                   False      False                 False
# 4                                   False      False                 False
# ...                                   ...        ...                   ...
# 2474                                False      False                 False
# 2475                                False      False                 False
# 2476                                False      False                 False
# 2477                                False      False                 False
# 2478                                False      False                 False
#
#       ...  Particules (E-06 disease inc./kg de produit)  \
# 0     ...                                         False
# 1     ...                                         False
# 2     ...                                         False
# 3     ...                                         False
# 4     ...                                         False
# ...   ...                                           ...
# 2474  ...                                         False
# 2475  ...                                         False
# 2476  ...                                         False
# 2477  ...                                         False
# 2478  ...                                         False
#
#       Acidification terrestre et eaux douces (mol H+ eq/kg de produit)  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 2474                                              False
# 2475                                              False
# 2476                                              False
# 2477                                              False
# 2478                                              False
#
#       Eutrophisation terreste (mol N eq/kg de produit)  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ...                                                ...
# 2474                                             False
# 2475                                             False
# 2476                                             False
# 2477                                             False
# 2478                                             False
#
#       Eutrophisation eaux douces (E-03 kg P eq/kg de produit)  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 2474                                              False
# 2475                                              False
# 2476                                              False
# 2477                                              False
# 2478                                              False
#
#       Eutrophisation marine (E-03 kg N eq/kg de produit)  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 2474                                              False
# 2475                                              False
# 2476                                              False
# 2477                                              False
# 2478                                              False
#
#       Utilisation du sol (Pt/kg de produit)  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
# ...                                     ...
# 2474                                  False
# 2475                                  False
# 2476                                  False
# 2477                                  False
# 2478                                  False
#
#       Écotoxicité pour écosystèmes aquatiques d'eau douce (CTUe/kg de produit)  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 2474                                              False
# 2475                                              False
# 2476                                              False
# 2477                                              False
# 2478                                              False
#
#       Épuisement des ressources eau (m3 depriv./kg de produit)  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 2474                                              False
# 2475                                              False
# 2476                                              False
# 2477                                              False
# 2478                                              False
#
#       Épuisement des ressources énergétiques (MJ/kg de produit)  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 2474                                              False
# 2475                                              False
# 2476                                              False
# 2477                                              False
# 2478                                              False
#
#       Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit)
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 2474                                              False
# 2475                                              False
# 2476                                              False
# 2477                                              False
# 2478                                              False
#
# [2479 rows x 27 columns]

# %% [markdown]
# ### Synthèse sur la partie exploration des données de la table synthese

# %% [markdown]
# <div class="alert alert-info" role="alert">
# La table synthese résume l'effet de chacun des produits agricoles sur l'environnement. Les premières colonnes introduisent le produit en question (nom complet, code, groupe alimentaire, ..), tandis que les colonnes restantes indiquent l'impact sur l'environnement.
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
# Dans ce qui précède, nous avons exploré la table data_synthese de la base de données Agribalyse, nous allons résumer dans les points suivants les différentes méthodes et fonctions utilisées pour réaliser l'exploration :
# <ul>
#     <li>Affichage des variables de cette table</li>
#     <li>Affichage des types de données</li>
#     <li>Affichage des données sous forme de histogrammes afin de construire une idée sur la distribution et la dispersion des données dans la base de données</li>
#     <li>Affichage d'une description de chaque attribut de la table data_synthese : moyenne, max, min, nombre de val distinctes, quartiles, médiane..</li>
# </ul>
#
#
# Nous avons également analysé chaque attribut de la base de données, et avons essayé de comprerndre le(s) liens qu'il peut avoir avec d'autres attributs de la base de données, et ceci afin de cibler la liste des attributs qui peuvent être intéressants à considérer comme étiquettes (labels) pour un problème de classification.
#
# Pour cela nous pouvons considérer les problèmes d'apprentissage supervisé (de classification) suivants:
# - un problème de classification multiclasse avec comme attribut label DQR.
# - un problème de classification binaire avec comme attribut label Transport par avion.
# - un problème de classification multiclasse avec comme attribut label Score unique.
# - un problème de classification multiclasse avec comme attribut label Changement climatique (kg CO2 eq/kg de produit)
# - un problème de classification multiclasse avec comme attribut label Appauvrissement de la couche d'ozone (E-06 kg CVC11 eq/kg de produit)
# - un problème de classification multiclasse avec comme attribut label Rayonnements ionisants (kBq U-235 eq/kg de produit)
# - un problème de classification multiclasse avec comme attribut label Formation photochimique d'ozone (E-03 kg NMVOC eq/kg de produit)
# - un problème de classification multiclasse avec comme attribut label Particules (E-06 disease inc./kg de produit)
# - un problème de classification multiclasse avec comme attribut label Acidification terrestre et eaux douces (mol H+ eq/kg de produit)
# - un problème de classification binaire avec comme attribut label Eutrophisation (regroupant les deux colonnes Eutrophisation par le biais de la moyenne)
# - un problème de classification multiclasse avec comme attribut label Eutrophisation eaux douces (E-03 kg P eq/kg de produit)
# - un problème de classification multiclasse avec comme attribut label Eutrophisation marine (E-03 kg N eq/kg de produit)
#
# ***
# Concernant les problèmes non supervisés, nous allons essayer de tourner l'algorithme de k-moyennes afin de trouver des relations ou groupes (clusters qui peuvent exister entre les données).
# </div>

# %%
data_synthese['DQR - Note de qualité de la donnée (1 excellente ; 5 très faible)'].sample(5)
# Out:
# 2227    3.16
# 2081    2.46
# 234     2.29
# 379     3.52
# 536     3.05
# Name: DQR - Note de qualité de la donnée (1 excellente ; 5 très faible), dtype: float64

# %%
synthese_arr = np.array(data_synthese)
synthese_arr.shape
# Out:
# (2479, 27)

# %%
data_synthese['DQR - Note de qualité de la donnée (1 excellente ; 5 très faible)'].describe()
# Out:
# count    2479.000000
# mean        2.810097
# std         0.542470
# min         1.600000
# 25%         2.430000
# 50%         2.760000
# 75%         3.110000
# max         4.870000
# Name: DQR - Note de qualité de la donnée (1 excellente ; 5 très faible), dtype: float64

# %%
boxplot = data_synthese.boxplot(column=["DQR - Note de qualité de la donnée (1 excellente ; 5 très faible)"])

# %%
plt.hist(synthese_arr[:,11])
# Out:
# (array([ 81., 309., 548., 511., 522., 214., 219.,  44.,  27.,   4.]),
#  array([1.6, 1.927, 2.254, 2.5810000000000004, 2.9080000000000004,
#         3.2350000000000003, 3.5620000000000003, 3.8890000000000002, 4.216,
#         4.543, 4.87], dtype=object),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# <div class="alert alert-info" role="alert">
#  Après étude des trois tables (synthèse, ingrédients et étapes), nous avon décidé de concentrer le travail sur la table synthèse, cette dernière regroupe le plus d'informations sur la base de données globale et permet d'avoir une vision plus générale sur les problème à réaliser.
# </div>

# %% [markdown]
# -------------

# %% [markdown]
# ## 1.2 Pré-traitement de données (Data Cleaning)

# %% [markdown]
# <div class="alert alert-info" role="alert">
# Dans cette partie nous allons appliquer des transformations sur les données afin de les rendre plus significatifs, et permettre l'entrainement de nos modèles sur ces données.
# Les méthodes de transformation utilisées sont les suivantes:
#     <ul>
#         <li>Traitement des valeurs aberrantes.</li>
#         <li>Traitement des valeurs nulles.</li>
#         <li>Traitement des attributs catégoriels.</li>
#         <li>Normalisation des données (transformer les données en une répartition centrée et réduite).</li>
#     </ul>
# </div>

# %% [markdown]
# ### Etiquette : DQR

# %%
sc = StandardScaler()
d = data_synthese.copy()

# Supprimer les attributs non descriminats dans notre apprentisage
d.drop(['Code AGB', 'Code CIQUAL','Nom du Produit en Français','Saisonnalité','LCI Name'],inplace = True, axis = 1)

# Traiter les valeurs aberrantes
for c in d.columns:
    try: ut.treat_outliers(d,c)
    except: continue

# Traiter l'attribut étiquette à part
d1 = d[d.columns.difference(['DQR - Note de qualité de la donnée (1 excellente ; 5 très faible)'])]

# Normaliser les valeurs numériques
num_d = d1.select_dtypes(exclude=['object'])
d[num_d.columns] = sc.fit_transform(num_d)

# Discrétiser les variables catégorielles
d = pd.get_dummies(d)

# %% [markdown]
# ## 1.3 Entrainement des modèles

# %% [markdown]
# ### Apprentissage supervisé - problème de classification

# %% [markdown]
# ### Etiquette : DQR - Note de qualité de la donnée

# %%
X = np.array(d[d.columns.difference(['DQR - Note de qualité de la donnée (1 excellente ; 5 très faible)'])])
Y = np.array(d['DQR - Note de qualité de la donnée (1 excellente ; 5 très faible)'])

# %%
plt.hist(Y)
# Out:
# (array([ 33., 141., 356., 478., 408., 495., 176., 176., 170.,  46.]),
#  array([1.6  , 1.852, 2.104, 2.356, 2.608, 2.86 , 3.112, 3.364, 3.616,
#         3.868, 4.12 ]),
#  <BarContainer object of 10 artists>)

# %%
# Target 1 : DQR Qualité

Y = np.where(Y<1,0,Y)
Y = np.where((Y>=1) & (Y<2),1,Y)
Y = np.where((Y>=2) & (Y<3),2,Y)
Y = np.where((Y>=3) & (Y<4),3,Y)
Y = np.where((Y>=4),4,Y)

plt.hist(Y)
# Out:
# (array([ 128.,    0.,    0., 1565.,    0.,    0.,  750.,    0.,    0.,
#           36.]),
#  array([1. , 1.3, 1.6, 1.9, 2.2, 2.5, 2.8, 3.1, 3.4, 3.7, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
Q1 = np.percentile(Y, 20,interpolation = 'midpoint')
Q2 = np.percentile(Y, 40,interpolation = 'midpoint')
Q3 = np.percentile(Y, 60,interpolation = 'midpoint')
Q4 = np.percentile(Y, 80,interpolation = 'midpoint')

Y = np.where(Y<Q1,0,Y)
Y = np.where((Y>Q1) & (Y<Q2),1,Y)
Y = np.where((Y>Q2) & (Y<Q3),2,Y)
Y = np.where((Y>Q3) & (Y<Q4),3,Y)
Y = np.where((Y>Q4),4,Y)

plt.hist(Y)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_17604\2885306287.py:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   Q1 = np.percentile(Y, 20,interpolation = 'midpoint')
# C:\Users\PC\AppData\Local\Temp\ipykernel_17604\2885306287.py:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   Q2 = np.percentile(Y, 40,interpolation = 'midpoint')
# C:\Users\PC\AppData\Local\Temp\ipykernel_17604\2885306287.py:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   Q3 = np.percentile(Y, 60,interpolation = 'midpoint')
# C:\Users\PC\AppData\Local\Temp\ipykernel_17604\2885306287.py:4: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   Q4 = np.percentile(Y, 80,interpolation = 'midpoint')
# (array([484.,   0., 456.,   0.,   0., 495.,  46., 502.,   0., 496.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
div = int(0.75*len(X))
Xapp,Yapp = X[:div,:], Y[:div]
Xtest,Ytest = X[div:,:], Y[div:]
Xr = ut.PCA(X)
Xrapp, Xrtest = ut.PCA(Xapp), ut.PCA(Xtest)
# Out:
# le nombre de valeurs propres : 120
# Dimension de l'ensemble de départ :  120
# Dimension de l'ensemble après transformation :  2
# ---
# le nombre de valeurs propres : 120
# Dimension de l'ensemble de départ :  120
# Dimension de l'ensemble après transformation :  2
# ---
# le nombre de valeurs propres : 120
# Dimension de l'ensemble de départ :  120
# Dimension de l'ensemble après transformation :  2
# ---

# %%
plt.figure()
plt.scatter(Xr[Y==0,0],Xr[Y==0,1])
plt.scatter(Xr[Y==1,0],Xr[Y==1,1])
plt.scatter(Xr[Y==2,0],Xr[Y==2,1])
plt.scatter(Xr[Y==3,0],Xr[Y==3,1])
plt.scatter(Xr[Y==4,0],Xr[Y==4,1])
# ####################################
plt.legend(np.arange(10))

# %%
X.shape
# Out:
# (2479, 120)

# %% [markdown]
# ### <font color='blue'>Algorithme de k-ppv</font>

# %%
# Entrainement du modèle perceptron multiclasse avec l'algorithme k-ppv et k = 3
# Méthode d'évaluation : Validation croisée
modelKNN_MC = cl.ClassifierKNN_MC(120, 3, nb_class=5)
ut.train_cv(modelKNN_MC, X,Y)
# Out:
# Kfold 0 : train 0.88  -  test 0.78
# Kfold 1 : train 0.88  -  test 0.83
# Kfold 2 : train 0.88  -  test 0.8
# Kfold 3 : train 0.88  -  test 0.81
# Kfold 4 : train 0.87  -  test 0.81
# Kfold 5 : train 0.89  -  test 0.78
# Kfold 6 : train 0.87  -  test 0.81
# Kfold 7 : train 0.88  -  test 0.79
# Kfold 8 : train 0.88  -  test 0.79
# Kfold 9 : train 0.88  -  test 0.83
# ---
# Moyenne train set: 0.88
# Moyenne test  set: 0.8
# Résultat en 8.2e+01 secondes
# ---

# %%
# Entrainement du modèle perceptron multiclasse avec l'algorithme k-ppv et k = 5
# Méthode d'évaluation : Validation croisée
modelKNN_MC = cl.ClassifierKNN_MC(120, 5, nb_class=5)
ut.train_cv(modelKNN_MC, X,Y)
# Out:
# Kfold 0 : train 0.85  -  test 0.77
# Kfold 1 : train 0.85  -  test 0.77
# Kfold 2 : train 0.86  -  test 0.78
# Kfold 3 : train 0.85  -  test 0.8
# Kfold 4 : train 0.84  -  test 0.8
# Kfold 5 : train 0.84  -  test 0.8
# Kfold 6 : train 0.85  -  test 0.8
# Kfold 7 : train 0.84  -  test 0.79
# Kfold 8 : train 0.85  -  test 0.78
# Kfold 9 : train 0.85  -  test 0.8
# ---
# Moyenne train set: 0.85
# Moyenne test  set: 0.79
# Résultat en 7.7e+01 secondes
# ---

# %% [markdown]
# ### <font color='blue'>Algorithme du perceptron multiclasse</font>

# %%
# Entrainement du modèle perceptron multiclasse
# Méthode d'évaluation : Validation croisée
learning_rate = 1e-2
input_dimension = 120
perceptron = cl.PerceptronMultiOOA(input_dimension, learning_rate, nbC=5, init=0)
ut.train_cv(perceptron, X,Y)
# Out:
# Kfold 0 : train 0.69  -  test 0.69
# Kfold 1 : train 0.74  -  test 0.68
# Kfold 2 : train 0.68  -  test 0.68
# Kfold 3 : train 0.59  -  test 0.66
# Kfold 4 : train 0.73  -  test 0.77
# Kfold 5 : train 0.75  -  test 0.72
# Kfold 6 : train 0.72  -  test 0.71
# Kfold 7 : train 0.76  -  test 0.73
# Kfold 8 : train 0.75  -  test 0.68
# Kfold 9 : train 0.75  -  test 0.75
# ---
# Moyenne train set: 0.72
# Moyenne test  set: 0.71
# Résultat en 6.5e+01 secondes
# ---

# %%
# Sans utilisation de la procédure de cross validation
# Entrainement du modèle sur le train_set, et évaluation sur le test_set
# Perceptron multiclasse

# Création d'un perceptron avec initialisation à 0 et le learning_rate ci-dessous:
learning_rate = 0.01
input_dimension = 120
perceptron = cl.PerceptronMultiOOA(input_dimension, learning_rate, nbC=5, init=0)
tic = time.time()
# Entrainement du modèle
perceptron.train(Xapp, Yapp)
toc = time.time()
print("---")
print("Précision train set : ", round(perceptron.accuracy(Xapp, Yapp),2)*100,"%")
print("Précision test set : ", round(perceptron.accuracy(Xtest, Ytest),2)*100,"%")
print(f"Résultat en {(toc-tic):.4} secondes")
# Out:
# ---
# Précision train set :  74.0 %
# Précision test set :  74.0 %
# Résultat en 6.634 secondes

# %% [markdown]
# ### <font color='blue'>Algorithme de arbre de décision</font>

# %%
# De même, les classes de Classifiers sont utilisables en mettant classif. devant leur nom:
# Création d'un perceptron
arbre_1 = cl.ClassifierArbreNumerique(120, 0.30)

# Construction de l'arbre de décision à partir du dataset généré plus haut
arbre_1.train(Xapp,Yapp)
print("Accuracy (train): ", round(arbre_1.accuracy(Xapp,Yapp),2)*100)
print("Accuracy (test): ", round(arbre_1.accuracy(Xtest,Ytest),2)*100)

# Construction de la représentation graphique (affichage)
graphe_arbre_1 = gv.Digraph(format='png')
arbre_1.affiche(graphe_arbre_1)
# Out:
# Accuracy (train):  93.0
# Accuracy (test):  70.0

# %%
# Affichage du graphe obtenu:
# graphe_arbre_1

# %% [markdown]
# <div class="alert alert-info" role="alert">
#  Ce que nous avons réalisé jusque là avec comme étiquette DQR - Note de qualité de la donnée (1 excellente ; 5 très faible):
#     <ul>
#     <li>Division des valeurs de l'attribut DQR afin de construire des classes de prédiction (05 classes).</li>
#     <li>Application de l'algorithme k-ppv avec comme valeur de k = 3.</li>
#     <li>Application de l'algorithme du perceptron.</li>
#     <li>Application de l'algorithme d'arbre de décision.</li>
#     </ul>
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   Analyse des résultats:
#     L'algorithme de k-ppv donne nettement de meilleurs résultats que les deux autres algorithmes utilisés.
# </div>

# %% [markdown]
# ### Etiquette :  Score Unique

# %% [markdown]
# Construction de classe pour un problème de classification binaire (division par la médiane)

# %%
sc = StandardScaler()
d = data_synthese.copy()
# get numeric data
#um_d = d.select_dtypes(exclude=['object'])
cols = d.columns

# Supprimer les attributs non descriminats dans notre apprentisage
d.drop(['Code AGB', 'Code CIQUAL','Nom du Produit en Français','Saisonnalité','LCI Name'],inplace = True, axis = 1)

for c in d.columns:
    try: ut.treat_outliers(d,c)
    except: continue

c = ['Score unique EF (mPt/kg de produit)']
d1 = d[d.columns.difference(c)]
num_d = d1.select_dtypes(exclude=['object'])
# update the cols with their normalized values
d[num_d.columns] = sc.fit_transform(num_d)
d = pd.get_dummies(d)

# %%
c2 = ['Score unique EF (mPt/kg de produit)']
X2 = np.array(d[d.columns.difference(c2)])
Y2 = np.array(d[c2])
plt.hist(Y2)
# Out:
# (array([723., 505., 591., 119., 184.,  70.,  97.,  65.,  46.,  79.]),
#  array([0.00613024, 0.19527024, 0.38441023, 0.57355023, 0.76269022,
#         0.95183022, 1.14097022, 1.33011021, 1.51925021, 1.7083902 ,
#         1.8975302 ]),
#  <BarContainer object of 10 artists>)

# %%
Q2 = np.percentile(Y2, 50,interpolation = 'midpoint')
Y2 = np.where(Y2<Q2,-1,1)
plt.hist(Y2)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_17604\3499253807.py:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   Q2 = np.percentile(Y2, 50,interpolation = 'midpoint')
# (array([1239.,    0.,    0.,    0.,    0.,    0.,    0.,    0.,    0.,
#         1240.]),
#  array([-1. , -0.8, -0.6, -0.4, -0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ]),
#  <BarContainer object of 10 artists>)

# %%
div = int(0.75*len(X2))
X2app,Y2app = X2[:div,:], Y2[:div]
X2test,Y2test = X2[div:,:], Y2[div:]
X2rapp, X2rtest = ut.PCA(Xapp), ut.PCA(Xtest)
# Out:
# le nombre de valeurs propres : 120
# Dimension de l'ensemble de départ :  120
# Dimension de l'ensemble après transformation :  2
# ---
# le nombre de valeurs propres : 120
# Dimension de l'ensemble de départ :  120
# Dimension de l'ensemble après transformation :  2
# ---

# %% [markdown]
# ### <font color='blue'>Algorithme de k-ppv</font>

# %%
# Entrainement du modèle perceptron multiclasse avec l'algorithme k-ppv et k = 3
modelKNN = cl.ClassifierKNN(120, 3)
ut.train_cv(modelKNN,X2,Y2)
# Out:
# Kfold 0 : train 0.99  -  test 0.96
# Kfold 1 : train 0.99  -  test 0.96
# Kfold 2 : train 0.99  -  test 0.98
# Kfold 3 : train 0.99  -  test 0.96
# Kfold 4 : train 0.99  -  test 0.98
# Kfold 5 : train 0.99  -  test 0.97
# Kfold 6 : train 0.99  -  test 0.97
# Kfold 7 : train 0.99  -  test 0.97
# Kfold 8 : train 0.99  -  test 0.98
# Kfold 9 : train 0.99  -  test 0.97
# ---
# Moyenne train set: 0.99
# Moyenne test  set: 0.97
# Résultat en 3.7e+02 secondes
# ---

# %% [markdown]
# ### <font color='blue'>Algorithme du perceptron binaire</font>

# %%
# Sans utilisation de la procédure de cross validation
# Entrainement du modèle sur le train_set, et évaluation sur le test_set

# Création d'un perceptron avec initialisation à 0 et le learning_rate ci-dessous:
learning_rate = 0.1
input_dimension = 120
perceptron = cl.ClassifierPerceptron(input_dimension, learning_rate)
tic = time.time()
# Entrainement du modèle
perceptron.train(X2app, Y2app)
toc = time.time()
print("---")
print("Précision train set : ", round(perceptron.accuracy(X2app, Y2app),2)*100,"%")
print("Précision test set : ", round(perceptron.accuracy(X2test, Y2test),2)*100,"%")
print(f"Résultat en {(toc-tic):.4} secondes")
# Out:
# ---
# Précision train set :  99.0 %
# Précision test set :  96.0 %
# Résultat en 3.289 secondes

# %%
# Entrainement du modèle perceptron binaire
# Utilisation de la procédure de validation croisée
learning_rate = 0.01
input_dimension = 120
perceptron = cl.ClassifierPerceptron(input_dimension, learning_rate)
ut.train_cv(perceptron,X2,Y2)
# Out:
# Kfold 0 : train 0.98  -  test 0.96
# Kfold 1 : train 0.98  -  test 0.97
# Kfold 2 : train 0.98  -  test 0.96
# Kfold 3 : train 0.98  -  test 0.99
# Kfold 4 : train 0.98  -  test 0.97
# Kfold 5 : train 0.98  -  test 0.98
# Kfold 6 : train 0.98  -  test 0.98
# Kfold 7 : train 0.98  -  test 0.98
# Kfold 8 : train 0.98  -  test 0.97
# Kfold 9 : train 0.98  -  test 0.98
# ---
# Moyenne train set: 0.98
# Moyenne test  set: 0.97
# Résultat en 2.9e+01 secondes
# ---

# %% [markdown]
# ### <font color='blue'>Algorithme de arbre de décision</font>

# %%
# De même, les classes de Classifiers sont utilisables en mettant classif. devant leur nom:
# Création d'un perceptron
arbre_2 = cl.ClassifierArbreNumerique(120, 0.30)

# Construction de l'arbre de décision à partir du dataset généré plus haut
arbre_2.train(X2app,Y2app)
print("Accuracy (train): ", round(arbre_2.accuracy(X2app,Y2app),2)*100)
print("Accuracy (test): ", round(arbre_2.accuracy(X2test,Y2test),2)*100)

# Construction de la représentation graphique (affichage)
graphe_arbre_2 = gv.Digraph(format='png')
arbre_2.affiche(graphe_arbre_2)

# Affichage du graphe obtenu:
# graphe_arbre_2
# Out:
# Accuracy (train):  97.0
# Accuracy (test):  94.0

# %% [markdown]
# ### <font color='blue'>Algorithme de forêt aléatoire</font>

# %%
# Entrainement du modèle forêt aléatoire
# Méthode d'évaluation : Entrainement du modèle sur le train_set, et évaluation sur le test_set
# Nombre de modèles testés: 5 (bags)

random.seed(42)

foret_1 = cl.ClassifierBaggingTree(5,0.3,0.0,True)
foret_1.train((X2app,Y2app))

# Accuracy
print("Précision train set:",round(foret_1.accuracy(X2app,Y2app),2))
print("Précision test set:",round(foret_1.accuracy(X2test,Y2test),2))
# Out:
# Précision train set: 0.99
# Précision test set: 0.96

# %% [markdown]
# <div class="alert alert-info" role="alert">
#  Ce que nous avons réalisé jusque là avec comme étiquette Score Unique :
#     <ul>
#     <li>Division des valeurs de l'attribut Score afin de construire des classes de prédiction (02 classes).</li>
#     <li>Application de l'algorithme k-ppv avec comme valeur de k = 3.</li>
#     <li>Application de l'algorithme du perceptron (avec cross-validation et avec train set evaluation).</li>
#     <li>Application de l'algorithme d'arbre de décision.</li>
#     <li>Application de l'algorithme de forêt aleatoire.</li>
#     </ul>
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   Analyse des résultats:
#     Tout les algorithmes utilisés donnent des taux de bonnes prédictions très élevés.
# </div>

# %% [markdown]
# ### Etiquette : Eutrophisation

# %% [markdown]
# Construction de classes en combinant deux attributs (Eutrophisation eaux douces, Eutrophisation marine) par la moyenne, problème de classification binaire (divisé sur la médiane).

# %%
sc = StandardScaler()
d = data_synthese.copy()
# get numeric data
#um_d = d.select_dtypes(exclude=['object'])
cols = d.columns
#d[cols] = d[cols].apply(pd.to_numeric, errors='coerce')

# Supprimer les attributs non descriminats dans notre apprentisage
d.drop(['Code AGB', 'Code CIQUAL','Nom du Produit en Français','Saisonnalité','LCI Name'],inplace = True, axis = 1)

for c in d.columns:
    try: ut.treat_outliers(d,c)
    except: continue
        
c = ['Eutrophisation eaux douces (E-03 kg P eq/kg de produit)','Eutrophisation marine (E-03 kg N eq/kg de produit)']
d1 = d[d.columns.difference(c)]
num_d = d1.select_dtypes(exclude=['object'])
# update the cols with their normalized values
d[num_d.columns] = sc.fit_transform(num_d)
d = pd.get_dummies(d)

# %%
X3 = np.array(d[d.columns.difference(c)])
Y3 = np.mean(np.array(d[c]),axis=1)
plt.hist(Y3)
# Out:
# (array([762., 411., 684., 199., 164.,  70.,  60.,  50.,  40.,  39.]),
#  array([1.92458147e-02, 3.22786125e+00, 6.43647669e+00, 9.64509213e+00,
#         1.28537076e+01, 1.60623230e+01, 1.92709384e+01, 2.24795539e+01,
#         2.56881693e+01, 2.88967848e+01, 3.21054002e+01]),
#  <BarContainer object of 10 artists>)

# %%
div = int(0.75*len(X2))
X3app,Y3app = X3[:div,:], Y3[:div]
X3test,Y3test = X3[div:,:], Y3[div:]
X3rapp, X3rtest = ut.PCA(X3app), ut.PCA(X3test)
# Out:
# le nombre de valeurs propres : 119
# Dimension de l'ensemble de départ :  119
# Dimension de l'ensemble après transformation :  2
# ---
# le nombre de valeurs propres : 119
# Dimension de l'ensemble de départ :  119
# Dimension de l'ensemble après transformation :  2
# ---

# %%
X3.shape
# Out:
# (2479, 119)

# %%
Q2 = np.percentile(Y3, 50,interpolation = 'midpoint')
Y3 = np.where(Y3<Q2,-1,1)
plt.hist(Y3)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_17604\2127168690.py:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   Q2 = np.percentile(Y3, 50,interpolation = 'midpoint')
# (array([1229.,    0.,    0.,    0.,    0.,    0.,    0.,    0.,    0.,
#         1250.]),
#  array([-1. , -0.8, -0.6, -0.4, -0.2,  0. ,  0.2,  0.4,  0.6,  0.8,  1. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### <font color='blue'>Algorithme de k-ppv</font>

# %%
# Entrainement du modèle perceptron multiclasse avec l'algorithme k-ppv et k = 3
modelKNN = cl.ClassifierKNN(119, 3)
ut.train_cv(modelKNN,X3,Y3)
# Out:
# Kfold 0 : train 0.98  -  test 0.96
# Kfold 1 : train 0.98  -  test 0.96
# Kfold 2 : train 0.98  -  test 0.97
# Kfold 3 : train 0.98  -  test 0.98
# Kfold 4 : train 0.98  -  test 0.96
# Kfold 5 : train 0.98  -  test 0.96
# Kfold 6 : train 0.99  -  test 0.96
# Kfold 7 : train 0.99  -  test 0.96
# Kfold 8 : train 0.98  -  test 0.97
# Kfold 9 : train 0.98  -  test 0.97
# ---
# Moyenne train set: 0.98
# Moyenne test  set: 0.97
# Résultat en 3.4e+02 secondes
# ---

# %% [markdown]
# ### <font color='blue'>Algorithme du perceptron</font>

# %%
# Entrainement du modèle perceptron multiclasse
learning_rate = 0.01
input_dimension = 119
perceptron = cl.ClassifierPerceptron(input_dimension, learning_rate)
ut.train_cv(perceptron,X3,Y3)
# Out:
# Kfold 0 : train 0.94  -  test 0.89
# Kfold 1 : train 0.95  -  test 0.96
# Kfold 2 : train 0.94  -  test 0.91
# Kfold 3 : train 0.95  -  test 0.94
# Kfold 4 : train 0.94  -  test 0.94
# Kfold 5 : train 0.95  -  test 0.92
# Kfold 6 : train 0.94  -  test 0.94
# Kfold 7 : train 0.95  -  test 0.96
# Kfold 8 : train 0.94  -  test 0.93
# Kfold 9 : train 0.94  -  test 0.93
# ---
# Moyenne train set: 0.94
# Moyenne test  set: 0.93
# Résultat en 1.3e+01 secondes
# ---

# %% [markdown]
# ### <font color='blue'>Arbre de décision</font>

# %%
# De même, les classes de Classifiers sont utilisables en mettant classif. devant leur nom:
# Création d'un perceptron
arbre_2 = cl.ClassifierArbreNumerique(119, 0.30)

# Construction de l'arbre de décision à partir du dataset généré plus haut
arbre_2.train(X3app,Y3app)
print("Accuracy (train): ", round(arbre_2.accuracy(X3app,Y3app),2)*100)
print("Accuracy (test): ", round(arbre_2.accuracy(X3test,Y3test),2)*100)

# Construction de la représentation graphique (affichage)
graphe_arbre_2 = gv.Digraph(format='png')
arbre_2.affiche(graphe_arbre_2)

# Affichage du graphe obtenu:
graphe_arbre_2
# Out:
# Accuracy (train):  100.0
# Accuracy (test):  30.0

# %% [markdown]
# <div class="alert alert-info" role="alert">
#  Ce que nous avons réalisé jusque là avec comme étiquette Eutrophisation:
#     <ul>
#     <li>Combiner deux colonnes de l'attribut Eutrophisation ayant la même valeur sémantique et même unité de mesure.</li>
#     <li>Application de l'algorithme k-ppv avec comme valeur de k = 3.</li>
#     <li>Application de l'algorithme du perceptron.</li>
#     <li>Application de l'algorithme d'arbre de décision.</li>
#     </ul>
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   Analyse des résultats:
#     L'algorithme de k-ppv et l'arbre de décision donne nettement de meilleurs résultats que les deux autres algorithmes utilisés.
# </div>

# %% [markdown]
# ### Etiquette : Changement climatique

# %%
sc = StandardScaler()
d = data_synthese.copy()
# get numeric data
#um_d = d.select_dtypes(exclude=['object'])
cols = d.columns

# Supprimer les attributs non descriminats dans notre apprentisage
d.drop(['Code AGB', 'Code CIQUAL','Nom du Produit en Français','Saisonnalité','LCI Name'],inplace = True, axis = 1)

for c in d.columns:
    try: ut.treat_outliers(d,c)
    except: continue

c = ['Changement climatique (kg CO2 eq/kg de produit)']
d1 = d[d.columns.difference(c)]
num_d = d1.select_dtypes(exclude=['object'])
# update the cols with their normalized values
d[num_d.columns] = sc.fit_transform(num_d)
d = pd.get_dummies(d)

# %%
X4 = np.array(d[d.columns.difference(c)])
Y4 = np.mean(np.array(d[c]),axis=1)
plt.hist(Y4)
# Out:
# (array([784., 706., 232., 259., 205., 112.,  71.,  43.,  25.,  42.]),
#  array([ 0.02104661,  1.41172095,  2.80239529,  4.19306963,  5.58374397,
#          6.97441831,  8.36509264,  9.75576698, 11.14644132, 12.53711566,
#         13.92779   ]),
#  <BarContainer object of 10 artists>)

# %%
Q1 = np.percentile(Y4, 20,interpolation = 'midpoint')
Q2 = np.percentile(Y4, 40,interpolation = 'midpoint')
Q3 = np.percentile(Y4, 60,interpolation = 'midpoint')
Q4 = np.percentile(Y4, 80,interpolation = 'midpoint')

Y4 = np.where(Y4<Q1,0,Y4)
Y4 = np.where((Y4>Q1) & (Y4<Q2),1,Y4)
Y4 = np.where((Y4>Q2) & (Y4<Q3),2,Y4)
Y4 = np.where((Y4>Q3) & (Y4<Q4),3,Y4)
Y4 = np.where((Y4>Q4),4,Y4)

plt.hist(Y4)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_17604\1564911575.py:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   Q1 = np.percentile(Y4, 20,interpolation = 'midpoint')
# C:\Users\PC\AppData\Local\Temp\ipykernel_17604\1564911575.py:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   Q2 = np.percentile(Y4, 40,interpolation = 'midpoint')
# C:\Users\PC\AppData\Local\Temp\ipykernel_17604\1564911575.py:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   Q3 = np.percentile(Y4, 60,interpolation = 'midpoint')
# C:\Users\PC\AppData\Local\Temp\ipykernel_17604\1564911575.py:4: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   Q4 = np.percentile(Y4, 80,interpolation = 'midpoint')
# (array([496.,   0., 492.,   0.,   7., 492.,   0., 496.,   0., 496.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
div = int(0.75*len(X4))
X4app,Y4app = X4[:div,:], Y4[:div]
X4test,Y4test = X4[div:,:], Y4[div:]
X4rapp, X4rtest = ut.PCA(X4app), ut.PCA(X4test)
# Out:
# le nombre de valeurs propres : 120
# Dimension de l'ensemble de départ :  120
# Dimension de l'ensemble après transformation :  2
# ---
# le nombre de valeurs propres : 120
# Dimension de l'ensemble de départ :  120
# Dimension de l'ensemble après transformation :  2
# ---

# %%
X4.shape
# Out:
# (2479, 120)

# %% [markdown]
# ### <font color='blue'>algorithme de k-ppv</font>

# %%
# Entrainement du modèle perceptron multiclasse avec l'algorithme k-ppv et k = 3
# Méthode d'évaluation : Validation croisée
modelKNN_MC = cl.ClassifierKNN_MC(120, 3, nb_class=5)
ut.train_cv(modelKNN_MC, X4,Y4)
# Out:
# Kfold 0 : train 0.93  -  test 0.88
# Kfold 1 : train 0.93  -  test 0.87
# Kfold 2 : train 0.93  -  test 0.89
# Kfold 3 : train 0.93  -  test 0.88
# Kfold 4 : train 0.93  -  test 0.86
# Kfold 5 : train 0.93  -  test 0.85
# Kfold 6 : train 0.92  -  test 0.86
# Kfold 7 : train 0.92  -  test 0.84
# Kfold 8 : train 0.93  -  test 0.85
# Kfold 9 : train 0.92  -  test 0.84
# ---
# Moyenne train set: 0.93
# Moyenne test  set: 0.86
# Résultat en 8.2e+01 secondes
# ---

# %% [markdown]
# ### <font color='blue'>Perceptron multiclasse</font>

# %%
# Entrainement du modèle perceptron multiclasse avec l'algorithme k-ppv et k = 3
# Méthode d'évaluation : Validation croisée
learning_rate = 1e-2
input_dimension = 120
perceptron = cl.PerceptronMultiOOA(input_dimension, learning_rate, nbC=5, init=0)
ut.train_cv(perceptron, X4,Y4)
# Out:
# Kfold 0 : train 0.74  -  test 0.72
# Kfold 1 : train 0.71  -  test 0.65
# Kfold 2 : train 0.71  -  test 0.68
# Kfold 3 : train 0.72  -  test 0.69
# Kfold 4 : train 0.66  -  test 0.67
# Kfold 5 : train 0.73  -  test 0.6
# Kfold 6 : train 0.73  -  test 0.67
# Kfold 7 : train 0.67  -  test 0.62
# Kfold 8 : train 0.67  -  test 0.63
# Kfold 9 : train 0.74  -  test 0.72
# ---
# Moyenne train set: 0.71
# Moyenne test  set: 0.66
# Résultat en 7.4e+01 secondes
# ---

# %% [markdown]
# ### <font color='blue'>Arbre de décision</font>

# %%
# De même, les classes de Classifiers sont utilisables en mettant classif. devant leur nom:
# Création d'un perceptron
arbre_2 = cl.ClassifierArbreNumerique(120, 0.30)

div = int(0.75*len(X4))
Xapp,Yapp = X4[:div,:], Y4[:div]
Xtest,Ytest = X4[div:,:], Y4[div:]
# Construction de l'arbre de décision à partir du dataset généré plus haut
arbre_2.train(Xapp,Yapp)
print("Accuracy (train): ", round(arbre_2.accuracy(Xapp,Yapp),2)*100)
print("Accuracy (test): ", round(arbre_2.accuracy(Xtest,Ytest),2)*100)

# Construction de la représentation graphique (affichage)
graphe_arbre_2 = gv.Digraph(format='png')
arbre_2.affiche(graphe_arbre_2)

# Affichage du graphe obtenu:
graphe_arbre_2
# Out:
# Accuracy (train):  98.0
# Accuracy (test):  78.0

# %% [markdown]
# <div class="alert alert-info" role="alert">
#  Ce que nous avons réalisé jusque là avec comme étiquette changement climatique:
#     <ul>
#     <li>Diviser, en utilisant les quartiles, les valeurs de l'attribut changement climatique en 05 classes.</li>
#     <li>Application de l'algorithme k-ppv avec comme valeur de k = 3.</li>
#     <li>Application de l'algorithme du perceptron.</li>
#     <li>Application de l'algorithme d'arbre de décision.</li>
#     </ul>
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   Analyse des résultats:
#     L'algorithme de k-ppv et l'arbre de décision donne nettement de meilleurs résultats que les deux autres algorithmes utilisés.
# </div>

# %% [markdown]
# ***

# %% [markdown]
# ## Apprentissage non supervisé

# %% [markdown]
# ## <font color='blue'>Clustering hiérarchique</font>

# %%
sc = StandardScaler()
d = data_synthese.copy()
# get numeric data
#um_d = d.select_dtypes(exclude=['object'])
cols = d.columns
d[cols] = d[cols].apply(pd.to_numeric, errors='coerce')

# Supprimer les attributs non descriminats dans notre apprentisage
d.drop(['Code AGB', 'Code CIQUAL','Nom du Produit en Français','Saisonnalité','LCI Name'],inplace = True, axis = 1)

for c in d.columns:
    try: ut.treat_outliers(d,c)
    except: continue
        
num_d = d.select_dtypes(exclude=['object'])
# update the cols with their normalized values
d[num_d.columns] = sc.fit_transform(num_d)
d = pd.get_dummies(d)
d[num_d.columns] = d[num_d.columns].fillna(0)

# %%
# Réduction de la dimensionnalité de la base d'apprentissage en utilisant PCA
Xr = ut.PCA(np.array(d))
data_2D = pd.DataFrame(Xr)
data_2D.columns = ['X','Y']
plt.scatter(data_2D["X"], data_2D["Y"])
# Out:
# le nombre de valeurs propres : 22
# Dimension de l'ensemble de départ :  22
# Dimension de l'ensemble après transformation :  2
# ---

# %%
# Normalisation des données
data_2D_norm =  clust.normalisation(data_2D)
plt.scatter(data_2D_norm["X"], data_2D_norm["Y"])

# %%
# L'application sur nos données:
clust.clustering_hierarchique(data_2D_norm.iloc[:20,:],False,True)
# Out:
# [[0, 2, 0.0, 2],
#  [9, 10, 0.0, 2],
#  [11, 13, 0.0, 2],
#  [12, 21, 0.0, 3],
#  [14, 16, 0.0, 2],
#  [17, 24, 0.0, 3],
#  [18, 19, 0.0, 2],
#  [15, 26, 0.008386272174085989, 3],
#  [8, 22, 0.00838627313571621, 3],
#  [1, 4, 0.011779509093845432, 2],
#  [20, 29, 0.01994038413021432, 4],
#  [3, 30, 0.04728548408741279, 5],
#  [23, 27, 0.052001839886563664, 6],
#  [6, 7, 0.07176522363512407, 2],
#  [5, 33, 0.14882291716106344, 3],
#  [25, 32, 0.16244156133280768, 9],
#  [28, 35, 0.25548787315891275, 12],
#  [31, 34, 0.2839314527769457, 8],
#  [36, 37, 0.7391124020917743, 20]]

# %% [markdown]
# ## <font color='blue'>Algorithme de k moyennes</font>

# %%
np.random.seed(42)   # supprimer cette ligne une fois la mise au point terminée

les_centres, l_affectation = clust.kmoyennes(2, data_2D_norm, 0.05, 100)

print("Affichage des centres: ",les_centres)
# Out:
# Iteration 1 Inertie : 89.21 Difference : 16.7604
# Iteration 2 Inertie : 86.1942 Difference : 3.0158
# Iteration 3 Inertie : 85.5658 Difference : 0.6283
# Iteration 4 Inertie : 85.3524 Difference : 0.2134
# Iteration 5 Inertie : 84.8536 Difference : 0.4988
# Iteration 6 Inertie : 84.5715 Difference : 0.2822
# Iteration 7 Inertie : 84.5437 Difference : 0.0278
# Affichage des centres:  [[0.39951455 0.48851374]
#  [0.80440489 0.47014143]]

# %%
clust.affiche_resultat(data_2D_norm,les_centres,l_affectation)
# Out:
# C:\Users\PC\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\collections.py:200: ComplexWarning: Casting complex values to real discards the imaginary part
#   offsets = np.asanyarray(offsets, float)

# %%
np.random.seed(42)   # supprimer cette ligne une fois la mise au point terminée

les_centres, l_affectation = clust.kmoyennes(3, data_2D_norm, 0.05, 100)

print("Affichage des centres: ",les_centres)

print("---")
print("Dunn index : ", clust.dunn_index(les_centres))
# Out:
# Iteration 1 Inertie : 57.2088 Difference : 3.0412
# Iteration 2 Inertie : 56.2669 Difference : 0.9419
# Iteration 3 Inertie : 55.9026 Difference : 0.3643
# Iteration 4 Inertie : 55.7834 Difference : 0.1192
# Iteration 5 Inertie : 55.7003 Difference : 0.0831
# Iteration 6 Inertie : 55.6329 Difference : 0.0674
# Iteration 7 Inertie : 55.624 Difference : 0.0089
# Affichage des centres:  [[0.54935472 0.55143015]
#  [0.84374549 0.46578335]
#  [0.26597415 0.36104819]]
# ---
# Dunn index :  0.31

# %%
clust.affiche_resultat(data_2D_norm,les_centres,l_affectation)

# %%
np.random.seed(42)   # supprimer cette ligne une fois la mise au point terminée

les_centres, l_affectation = clust.kmoyennes(5, data_2D_norm, 0.05, 100)

print("Affichage des centres: ",les_centres)

print("Dunn index : ", clust.dunn_index(les_centres))

clust.affiche_resultat(data_2D_norm,les_centres,l_affectation)
# Out:
# Iteration 1 Inertie : 36.9452 Difference : 9.2438
# Iteration 2 Inertie : 32.1447 Difference : 4.8004
# Iteration 3 Inertie : 30.5958 Difference : 1.5489
# Iteration 4 Inertie : 29.7411 Difference : 0.8548
# Iteration 5 Inertie : 29.4193 Difference : 0.3218
# Iteration 6 Inertie : 29.2174 Difference : 0.2019
# Iteration 7 Inertie : 29.2018 Difference : 0.0156
# Affichage des centres:  [[0.12905543+0.j 0.06703102+0.j]
#  [0.45039352+0.j 0.06779773+0.j]
#  [0.36959244+0.j 0.49438431+0.j]
#  [0.28873112+0.j 0.07773844+0.j]
#  [0.69776585+0.j 0.19093372+0.j]]
# Dunn index :  0.04

# %%
np.random.seed(42)   # supprimer cette ligne une fois la mise au point terminée

les_centres, l_affectation = clust.kmoyennes(7, data_2D_norm, 0.05, 100)

print("Affichage des centres: ",les_centres)

print("Dunn index : ", clust.dunn_index(les_centres))

clust.affiche_resultat(data_2D_norm,les_centres,l_affectation)
# Out:
# Iteration 1 Inertie : 24.5279 Difference : 3.5528
# Iteration 2 Inertie : 23.1478 Difference : 1.3801
# Iteration 3 Inertie : 22.4612 Difference : 0.6867
# Iteration 4 Inertie : 22.0171 Difference : 0.4441
# Iteration 5 Inertie : 21.8392 Difference : 0.1779
# Iteration 6 Inertie : 21.7243 Difference : 0.1149
# Iteration 7 Inertie : 21.3808 Difference : 0.3435
# Iteration 8 Inertie : 20.7056 Difference : 0.6752
# Iteration 9 Inertie : 20.1476 Difference : 0.5579
# Iteration 10 Inertie : 19.7093 Difference : 0.4384
# Iteration 11 Inertie : 19.335 Difference : 0.3743
# Iteration 12 Inertie : 18.7349 Difference : 0.6001
# Iteration 13 Inertie : 18.3898 Difference : 0.3451
# Iteration 14 Inertie : 18.179 Difference : 0.2108
# Iteration 15 Inertie : 18.095 Difference : 0.084
# Iteration 16 Inertie : 17.9945 Difference : 0.1006
# Iteration 17 Inertie : 17.927 Difference : 0.0675
# Iteration 18 Inertie : 17.8962 Difference : 0.0308
# Affichage des centres:  [[0.25187023+0.j 0.05821437+0.j]
#  [0.60496185+0.j 0.07187899+0.j]
#  [0.36943276+0.j 0.23216575+0.j]
#  [0.39066338+0.j 0.03708299+0.j]
#  [0.73179931+0.j 0.29056063+0.j]
#  [0.3776717 +0.j 0.60017607+0.j]
#  [0.10814082+0.j 0.06779116+0.j]]
# Dunn index :  0.05

# %% [markdown]
# <div class="alert alert-info" role="alert">
#  Ce que nous avons réalisé jusque là dans le problème d'apprentissage non supervisé :
#     <ul>
#     <li>Numériser les données catégorielles et normaliser la valeurs.</li>
#     <li>Application de la réduction de la dimensionnalité avec PCA.</li>
#     <li>Application de l'algorithme de clustering hiérarchique sur les données réduites.</li>
#     <li>Application de l'algorithme de k-moyennes.</li>
#     </ul>
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   Analyse des résultats:
#     <h5>Clustering hiérarchique :</h5> à l'aide du dendrogramme, nous constatons que une division du problème en 3 classes (groupes ou clusters) est possible, cette dernière correspond, selon notre interprétation du problème aux groupes de produits agricoles ayant le même impact sur l'environnement. Il est à noter que l'algithme est très couteux en terme de temps d'exécution dans le cas ou la tailles des données est relativement importante.
#     <h5>Algorithme des k-moyennes:</h5> nous constatons que une division du problème en 5 classes (groupes ou clusters) est une bonne division, confirmé par la métrique d'évaluation utilisée qu'est l'index de Dunn, cette dernière correspond, selon notre interprétation du problème aux groupes de produits agricoles ayant le même impact sur l'environnement (tout attributs compris).
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Synthese:</b>
#     Ce projet nous a permis de découvrir concrêtement le métier d'un data scientist, allant de l'exploration et le pré traitements de données brutes, puis d'imaginer des problèmes de prédiction qui peuvent aider à la prise de décision dans le futur, nous pouvons résumer les notions apprises dans les quelques points suivant:
#     <ul>
#      <li>Exploration de données brutes</li>
#     <li>Visualisation de données</li>
#     <li>Pré traitement et transformation des données</li>
#     <li>Selection d'attributs et construction de classe</li>
#     <li>Application de modèles d'apprentissage supervisé/non supervisé</li>
#     <li>Evaluation des résultats et interprétation</li>
#     </ul>
# </div>

# %% [markdown]
# ***

# %% [markdown]
# # Exploration des bases de données Ingredient et Etape

# %% [markdown]
# # Base de données ingrédients

# %%
data_ingredient = pd.read_csv("Donnees_Agribalyse/detail_ingredient.csv")
data_ingredient.columns
print("Taille du dataset: ",data_ingredient.shape)
# Out:
# Taille du dataset:  (5671, 22)

# %%
data_ingredient.head(5)
# Out:
#    Ciqual AGB  Ciqual code              Nom Français  \
# 0       11168        11168  Sauce aïoli, préemballée
# 1       11168        11168  Sauce aïoli, préemballée
# 2       11168        11168  Sauce aïoli, préemballée
# 3       11168        11168  Sauce aïoli, préemballée
# 4       11168        11168  Sauce aïoli, préemballée
#
#                          Groupe d'aliment Sous-groupe d'aliment  \
# 0  aides culinaires et ingrédients divers                sauces
#                Groupe d'aliment                 Sous-groupe d'aliment  \
# 5666  lait et produits laitiers  produits laitiers frais et assimilés
# 5667  lait et produits laitiers  produits laitiers frais et assimilés
# 5668  lait et produits laitiers  produits laitiers frais et assimilés
# 5669  lait et produits laitiers  produits laitiers frais et assimilés
# 5670  lait et produits laitiers  produits laitiers frais et assimilés
#
#                                      LCI Name       Ingredients  \
# 5666  Yogurt, Greek-style, on a bed of fruits            Fraise
# 5667  Yogurt, Greek-style, on a bed of fruits     Autres étapes
# 5668               Yogurt, Greek-style, plain              Lait
# 5669               Yogurt, Greek-style, plain  Lait demi-écremé
# 5670               Yogurt, Greek-style, plain     Autres étapes
#
#       Score unique EF (mPt/kg de produit)  \
# 5666                             0.121232
# 5667                             0.070305
# 5668                             0.063101
# 5669                             0.106409
# 5670                             0.070305
#
#       Changement climatique (kg CO2 eq/kg de produit)  \
# 5666                                         0.113532
# 5667                                         0.549462
# 5668                                         0.693950
# 5669                                         1.198262
# 5670                                         0.549462
#
#       Appauvrissement de la couche d'ozone (E-06 kg CVC11 eq/kg de produit)  \
# 5666                                           0.637141
# 5667                                           0.115755
# 5668                                           0.010273
# 5669                                           0.031746
# 5670                                           0.115755
#
#       ...  Particules (E-06 disease inc./kg de produit)  \
# 5666  ...                                      0.027982
# 5667  ...                                      0.023034
# 5668  ...                                      0.043025
# 5669  ...                                      0.089744
# 5670  ...                                      0.023034
#
#       Acidification terrestre et eaux douces (mol H+ eq/kg de produit)  \
# 5666                                           0.000952
# 5667                                           0.002426
# 5668                                           0.006846
# 5669                                           0.013406
# 5670                                           0.002426
#
#       Eutrophisation terreste (mol N eq/kg de produit)  \
# 5666                                          0.003176
# 5667                                          0.007428
# 5668                                          0.029968
# 5669                                          0.058485
# 5670                                          0.007428
#
#       Eutrophisation eaux douces (E-03 kg P eq/kg de produit)  \
# 5666                                           0.035963
# 5667                                           0.080773
# 5668                                           0.047026
# 5669                                           0.107689
# 5670                                           0.080773
#
#       Eutrophisation marine (E-03 kg N eq/kg de produit)  \
# 5666                                           0.370286
# 5667                                           1.159934
# 5668                                           8.579385
# 5669                                           3.903060
# 5670                                           1.159934
#
#       Utilisation du sol (Pt/kg de produit)  \
# 5666                               3.561618
# 5667                               4.096425
# 5668                              62.085522
# 5669                              66.972761
# 5670                               4.096425
#
#       Écotoxicité pour écosystèmes aquatiques d'eau douce (CTUe/kg de produit)  \
# 5666                                         195.859930
# 5667                                           6.238759
# 5668                                           1.178242
# 5669                                          17.562407
# 5670                                           6.238759
#
#       Épuisement des ressources eau (m3 depriv./kg de produit)  \
# 5666                                           1.702002
# 5667                                           0.248905
# 5668                                           0.013914
# 5669                                           0.373698
# 5670                                           0.248905
#
#       Épuisement des ressources énergétiques (MJ/kg de produit)  \
# 5666                                           1.587775
# 5667                                          21.610336
# 5668                                           1.062461
# 5669                                           3.073724
# 5670                                          21.610336
#
#       Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit)
# 5666                                           3.330941
# 5667                                           1.176044
# 5668                                           0.019234
# 5669                                           0.642726
# 5670                                           1.176044
#
# [5 rows x 22 columns]

# %%
data_ingredient.columns
# Out:
# Index(['Ciqual AGB', 'Ciqual code', 'Nom Français', 'Groupe d'aliment',
#        'Sous-groupe d'aliment', 'LCI Name', 'Ingredients',
#        'Score unique EF (mPt/kg de produit)',
#        'Changement climatique (kg CO2 eq/kg de produit)',
#        'Appauvrissement de la couche d'ozone (E-06 kg CVC11 eq/kg de produit)',
#        'Rayonnements ionisants (kBq U-235 eq/kg de produit)',
#        'Formation photochimique d'ozone (E-03 kg NMVOC eq/kg de produit)',
#        'Particules (E-06 disease inc./kg de produit)',
#        'Acidification terrestre et eaux douces (mol H+ eq/kg de produit)',
#        'Eutrophisation terreste (mol N eq/kg de produit)',
#        'Eutrophisation eaux douces (E-03 kg P eq/kg de produit)',
#        'Eutrophisation marine (E-03 kg N eq/kg de produit)',
#        'Utilisation du sol (Pt/kg de produit)',
#        'Écotoxicité pour écosystèmes aquatiques d'eau douce (CTUe/kg de produit)',
#        'Épuisement des ressources eau (m3 depriv./kg de produit)',
#        'Épuisement des ressources énergétiques (MJ/kg de produit)',
#        'Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit)'],
#       dtype='object')

# %%
data_ingredient.describe()
# Out:
#          Ciqual AGB   Ciqual code  Score unique EF (mPt/kg de produit)  \
# count   5671.000000   5671.000000                          5671.000000
# mean   22163.993476  22163.993476                             0.094535
# std     9122.684878   9122.684878                             0.218044
# min     1007.000000   1007.000000                             0.000000
# 25%    16741.000000  16741.000000                             0.013456
# 50%    24686.000000  24686.000000                             0.041018
# 75%    25605.000000  25605.000000                             0.081438
# max    96778.000000  96778.000000                             3.097321
#
#        Changement climatique (kg CO2 eq/kg de produit)  \
# count                                      5671.000000
# mean                                          0.769163
# std                                           2.107535
# min                                          -0.006669
# 25%                                           0.061778
# 50%                                           0.214772
# 75%                                           0.585656
# max                                          35.890458
#
#        Appauvrissement de la couche d'ozone (E-06 kg CVC11 eq/kg de produit)  \
# count                                        5671.000000
# mean                                            0.067837
# std                                             0.165024
# min                                             0.000000
# 25%                                             0.006064
# 50%                                             0.016907
# 75%                                             0.093550
# max                                             3.460422
#
#        Rayonnements ionisants (kBq U-235 eq/kg de produit)  \
# count                                        5671.000000
# mean                                            0.225749
# std                                             0.757643
# min                                             0.000000
# 25%                                             0.006529
# 50%                                             0.022799
# 75%                                             0.143838
# max                                            33.388781
#
#        Formation photochimique d'ozone (E-03 kg NMVOC eq/kg de produit)  \
# count                                        5671.000000
# mean                                            2.375956
# std                                            10.514584
# min                                             0.000000
# 25%                                             0.261106
# 50%                                             0.772146
# 75%                                             1.594189
# max                                           323.582360
#
#        Particules (E-06 disease inc./kg de produit)  \
# count                                   5671.000000
# mean                                       0.070389
# std                                        0.211329
# min                                        0.000000
# 25%                                        0.006712
# 50%                                        0.024329
# 75%                                        0.045122
# max                                        3.283005
#
#        Acidification terrestre et eaux douces (mol H+ eq/kg de produit)  \
# count                                        5671.000000
# mean                                            0.009830
# std                                             0.030989
# min                                             0.000000
# 25%                                             0.000898
# 50%                                             0.002624
# 75%                                             0.006258
# max                                             0.488213
#
#        Eutrophisation terreste (mol N eq/kg de produit)  \
# count                                       5671.000000
# mean                                           0.039485
# std                                            0.126562
# min                                            0.000000
# 25%                                            0.003360
# 50%                                            0.008651
# 75%                                            0.026146
# max                                            2.170038
#
#        Eutrophisation eaux douces (E-03 kg P eq/kg de produit)  \
# count                                        5671.000000
# mean                                            0.116352
# std                                             0.260584
# min                                             0.000000
# 25%                                             0.018847
# 50%                                             0.053117
# 75%                                             0.107614
# max                                             8.978935
#
#        Eutrophisation marine (E-03 kg N eq/kg de produit)  \
# count                                        5671.000000
# mean                                            3.251455
# std                                             8.032954
# min                                             0.000000
# 25%                                             0.422507
# 50%                                             1.204835
# 75%                                             2.443920
# max                                           121.141130
#
#        Utilisation du sol (Pt/kg de produit)  \
# count                            5671.000000
# mean                               37.084758
# std                               131.995373
# min                               -15.575287
# 25%                                 3.216551
# 50%                                 8.562092
# 75%                                26.754006
# max                              2863.439100
#
#        Écotoxicité pour écosystèmes aquatiques d'eau douce (CTUe/kg de produit)  \
# count                                        5671.000000
# mean                                           18.626661
# std                                            49.080276
# min                                             0.000000
# 25%                                             2.818496
# 50%                                             6.664536
# 75%                                            15.312990
# max                                          1176.701700
#
#        Épuisement des ressources eau (m3 depriv./kg de produit)  \
# count                                        5671.000000
# mean                                            0.886282
# std                                             3.363757
# min                                             0.000000
# 25%                                             0.112265
# 50%                                             0.288104
# 75%                                             0.578456
# max                                            82.966840
#
#        Épuisement des ressources énergétiques (MJ/kg de produit)  \
# count                                        5671.000000
# mean                                            8.366909
# std                                            19.830675
# min                                             0.000000
# 25%                                             0.615664
# 50%                                             1.698155
# 75%                                            11.389242
# max                                           742.560020
#
#        Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit)
# count                                        5671.000000
# mean                                            1.134560
# std                                             2.062187
# min                                             0.000000
# 25%                                             0.167689
# 50%                                             0.459293
# 75%                                             1.256538
# max                                            30.719730

# %%
data_ingredient.info
# Out:
# <bound method DataFrame.info of       Ciqual AGB  Ciqual code                            Nom Français  \
# 0          11168        11168                Sauce aïoli, préemballée
# 1          11168        11168                Sauce aïoli, préemballée
# 2          11168        11168                Sauce aïoli, préemballée
# 3          11168        11168                Sauce aïoli, préemballée
# 4          11168        11168                Sauce aïoli, préemballée
# ...          ...          ...                                     ...
# 5666       19552        19552  Yaourt à la grecque, sur lit de fruits
# 5667       19552        19552  Yaourt à la grecque, sur lit de fruits
# 5668       19860        19860             Yaourt à la grecque, nature
# 5669       19860        19860             Yaourt à la grecque, nature
# 5670       19860        19860             Yaourt à la grecque, nature
#
#                             Groupe d'aliment  \
# 0     aides culinaires et ingrédients divers
# 1     aides culinaires et ingrédients divers
# 2     aides culinaires et ingrédients divers
# 3     aides culinaires et ingrédients divers
# 4     aides culinaires et ingrédients divers
# ...                                      ...
# 5666               lait et produits laitiers
# 5667               lait et produits laitiers
# 5668               lait et produits laitiers
# 5669               lait et produits laitiers
# 5670               lait et produits laitiers
#
#                      Sous-groupe d'aliment  \
# 0                                   sauces
# 1                                   sauces
# 2                                   sauces
# 3                                   sauces
# 4                                   sauces
# ...                                    ...
# 5666  produits laitiers frais et assimilés
# 5667  produits laitiers frais et assimilés
# 5668  produits laitiers frais et assimilés
# 5669  produits laitiers frais et assimilés
# 5670  produits laitiers frais et assimilés
#
#                                                LCI Name       Ingredients  \
# 0     Aioli sauce (garlic and olive oil mayonnaise),...       Jaune d'œuf
# 1     Aioli sauce (garlic and olive oil mayonnaise),...               Ail
# 2     Aioli sauce (garlic and olive oil mayonnaise),...     Jus de citron
# 3     Aioli sauce (garlic and olive oil mayonnaise),...     Huile d'olive
# 4     Aioli sauce (garlic and olive oil mayonnaise),...     Autres étapes
# ...                                                 ...               ...
# 5666            Yogurt, Greek-style, on a bed of fruits            Fraise
#
#       Écotoxicité pour écosystèmes aquatiques d'eau douce (CTUe/kg de produit)  \
# 0                                              7.404112
# 1                                              1.216336
# 2                                              2.625043
# 3                                            464.100950
# 4                                             11.433712
# ...                                                 ...
# 5666                                         195.859930
# 5667                                           6.238759
# 5668                                           1.178242
# 5669                                          17.562407
# 5670                                           6.238759
#
#       Épuisement des ressources eau (m3 depriv./kg de produit)  \
# 0                                              0.337769
# 1                                              0.291209
# 2                                              1.445978
# 3                                              9.374618
# 4                                              0.759522
# ...                                                 ...
# 5666                                           1.702002
# 5667                                           0.248905
# 5668                                           0.013914
# 5669                                           0.373698
# 5670                                           0.248905
#
#       Épuisement des ressources énergétiques (MJ/kg de produit)  \
# 0                                              1.475548
# 1                                              0.229937
# 2                                              0.793865
# 3                                             12.100965
# 4                                             22.626111
# ...                                                 ...
# 5666                                           1.587775
# 5667                                          21.610336
# 5668                                           1.062461
# 5669                                           3.073724
# 5670                                          21.610336
#
#       Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit)
# 0                                              0.251356
# 1                                              0.084028
# 2                                              0.203959
# 3                                              4.424012
# 4                                              1.278583
# ...                                                 ...
# 5666                                           3.330941
# 5667                                           1.176044
# 5668                                           0.019234
# 5669                                           0.642726
# 5670                                           1.176044
#
# [5671 rows x 22 columns]>

# %% [markdown]
# # Base de données Etape

# %%
data_etape = pd.read_csv("Donnees_Agribalyse/detail_etape.csv")
data_etape.columns
print("Taille du dataset: ",data_etape.shape)
# Out:
# Taille du dataset:  (2480, 102)

# %%
data_etape.head(5)
# Out:
#   Code AGB  Code CIQUAL                             Groupe d'aliment  \
# 0    12112        12112                    lait et produits laitiers
# 1    13712        13712  fruits, légumes, légumineuses et oléagineux
# 2    13713        13713  fruits, légumes, légumineuses et oléagineux
# 3    13714        13714  fruits, légumes, légumineuses et oléagineux
# 4    13715        13715  fruits, légumes, légumineuses et oléagineux
#
#   Sous-groupe d'aliment                      Nom du Produit en Français  \
# 0              fromages                                       Abondance
# 1                fruits      Abricot au sirop léger, appertisé, égoutté
# 2                fruits  Abricot au sirop léger, appertisé, non égoutté
# 3                fruits            Abricot au sirop, appertisé, égoutté
# 4                fruits        Abricot au sirop, appertisé, non égoutté
#
#                                       LCI Name   DQR  \
# 0            Abondance cheese, from cow's milk  2.24
# 1      Apricot, canned in light syrup, drained  2.46
# 2  Apricot, canned in light syrup, not drained  2.46
# 3           Apricot, in syrup, canned, drained  2.46
# 4       Apricot, in syrup, canned, not drained  2.44
#
#                                          Nom et code  \
# 0                                  Abondance (12112)
# 1  Abricot au sirop léger, appertisé, égoutté (13...
# 2  Abricot au sirop léger, appertisé, non égoutté...
# 3       Abricot au sirop, appertisé, égoutté (13714)
# 4   Abricot au sirop, appertisé, non égoutté (13715)
#
#    Score unique EF (mPt / kg de produit) - Agriculture  \
# 0                                           0.470679
# 1                                           0.061297
# 2                                           0.038249
# 3                                           0.061297
# 4                                           0.038249
#
#    Score unique EF (mPt / kg de produit) - Transformation  ...  \
# 0                                           0.046274       ...
# 1                                           0.075215       ...
# 2                                           0.046934       ...
# 3                                           0.075215       ...
# 4                                           0.046934       ...
#
#    Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit) - Agriculture  \
# 0                                           2.855985
# 1                                           1.281828
# 2                                           0.799861
# 3                                           1.281828
# 4                                           0.799861
#
#    Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit) - Transformation  \
# 0                                           0.552672
# 1                                           0.477989
# 2                                           0.298265
# 3                                           0.477989
# 4                                           0.298265
#
#    Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit) - Emballage  \
# 0                                           0.108718
# 1                                           0.220289
# 2                                           0.137461
# 3                                           0.220289
# 4                                           0.137461
#
#    Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit) - Transport  \
# 0                                           0.985193
# 1                                           0.679414
# 2                                           0.423954
# 3                                           0.679414
# 4                                           0.423954
#
#    Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit) - Supermarché et distribution  \
# 0                                           0.148203
# 1                                           0.263117
# 2                                           0.164185
# 3                                           0.263117
# 4                                           0.164185
#
#    Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit) - Consommation  \
# 0                                           0.042714
# 1                                           0.015426
# 2                                           0.000000
# 3                                           0.015426
# 4                                           0.000000
#
#    DQR - P  DQR - TiR  DQR - GR  DQR - TeR
# 0     2.84       2.05      1.18       2.87
# 1     2.25       3.62      1.96       2.01
# 2     2.25       3.62      1.96       2.01
# 3     2.25       3.62      1.96       2.01
# 4     2.21       3.65      1.92       1.97
#
# [5 rows x 102 columns]

# %%
data_etape.tail()
# Out:
#      Code AGB  Code CIQUAL           Groupe d'aliment  \
# 2475    19592        19592  lait et produits laitiers
# 2476    19593        19593  lait et produits laitiers
# 2477    19594        19594  lait et produits laitiers
# 2478    19598        19598  lait et produits laitiers
# 2479    19599        19599  lait et produits laitiers
#
#                      Sous-groupe d'aliment  \
# 2475  produits laitiers frais et assimilés
# 2476  produits laitiers frais et assimilés
# 2477  produits laitiers frais et assimilés
# 2478  produits laitiers frais et assimilés
# 2479  produits laitiers frais et assimilés
#
#                              Nom du Produit en Français  \
# 2475  Yaourt, lait fermenté ou spécialité laitière, ...
# 2476  Yaourt, lait fermenté ou spécialité laitière, ...
# 2477  Yaourt, lait fermenté ou spécialité laitière, ...
# 2478  Yaourt, lait fermenté ou spécialité laitière, ...
# 2479  Yaourt, lait fermenté ou spécialité laitière, ...
#
#                                                LCI Name   DQR  \
# 2475  Yogurt, fermented milk or dairy specialty, wit...  3.61
# 2476   Yogurt, fermented milk or dairy specialty, plain  2.04
# 2477  Yogurt, fermented milk or dairy specialty, pla...  2.48
# 2478  Yogurt, fermented milk or dairy specialty, pla...  1.90
# 2479  Yogurt, fermented milk or dairy specialty, pla...  1.90
#
#                                             Nom et code  \
# 2475  Yaourt, lait fermenté ou spécialité laitière, ...
# 2476  Yaourt, lait fermenté ou spécialité laitière, ...
# 2477  Yaourt, lait fermenté ou spécialité laitière, ...
# 2478  Yaourt, lait fermenté ou spécialité laitière, ...
# 2479  Yaourt, lait fermenté ou spécialité laitière, ...
#
#       Score unique EF (mPt / kg de produit) - Agriculture  \
# 2475                                           0.277819
# 2476                                           0.168020
# 2477                                           0.168020
# 2478                                           0.180150
# 2479                                           0.108344
#
#       Score unique EF (mPt / kg de produit) - Transformation  ...  \
# 2475                                           0.031048       ...
# 2476                                           0.031331       ...
# 2477                                           0.031331       ...
# 2478                                           0.039865       ...
# 2479                                           0.032225       ...
#
#       Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit) - Agriculture  \
# 2475                                           3.780829
# 2476                                           0.655855
# 2477                                           0.655855
# 2478                                           1.058970
# 2479                                           0.681681
#
#       Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit) -
épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit) - Agriculture  \
# count                                        2480.000000
# mean                                            6.525864
# std                                            18.238873
# min                                             0.000000
# 25%                                             1.213543
# 50%                                             2.855985
# 75%                                             6.795029
# max                                           253.140040
#
#        Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit) - Transformation  \
# count                                        2480.000000
# mean                                            0.775480
# std                                             1.332905
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.338031
# 75%                                             0.768554
# max                                            17.065159
#
#        Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit) - Emballage  \
# count                                        2480.000000
# mean                                            0.463087
# std                                             2.859853
# min                                             0.000000
# 25%                                             0.035759
# 50%                                             0.108718
# 75%                                             0.211733
# max                                            38.492361
#
#        Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit) - Transport  \
# count                                        2480.000000
# mean                                            0.991304
# std                                             1.061823
# min                                             0.004992
# 25%                                             0.513243
# 50%                                             0.747366
# 75%                                             0.957510
# max                                            14.273753
#
#        Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit) - Supermarché et distribution  \
# count                                        2480.000000
# mean                                            0.179595
# std                                             0.122986
# min                                             0.000724
# 25%                                             0.148203
# 50%                                             0.149025
# 75%                                             0.184238
# max                                             1.063113
#
#        Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit) - Consommation  \
# count                                        2480.000000
# mean                                            0.119258
# std                                             0.195082
# min                                             0.000000
# 25%                                             0.006102
# 50%                                             0.042714
# 75%                                             0.113261
# max                                             1.193836
#
#            DQR - P    DQR - TiR     DQR - GR    DQR - TeR
# count  2480.000000  2480.000000  2480.000000  2480.000000
# mean      3.073294     2.614226     2.450863     3.102117
# std       0.834341     0.833306     0.895195     0.978380
# min       1.310000     1.180000     1.050000     1.090000
# 25%       2.400000     2.020000     1.770000     2.340000
# 50%       2.920000     2.540000     2.340000     3.050000
# 75%       3.720000     3.130000     3.050000     3.650000
# max       5.000000     4.840000     4.840000     5.000000
#
# [8 rows x 96 columns]

# %%
for c in data_etape.columns:
    print(c)
# Out:
# Code AGB
# Code CIQUAL
# Groupe d'aliment
# Sous-groupe d'aliment
# Nom du Produit en Français
# LCI Name
# DQR
# Nom et code
# Score unique EF (mPt / kg de produit) - Agriculture
# Score unique EF (mPt / kg de produit) - Transformation
# Score unique EF (mPt / kg de produit) - Emballage
# Score unique EF (mPt / kg de produit) - Transport
# Score unique EF (mPt / kg de produit) - Supermarché et distribution
# Score unique EF (mPt / kg de produit) - Consommation
# Changement climatique (kg CO2 eq/kg de produit) - Agriculture
# Changement climatique (kg CO2 eq/kg de produit) - Transformation
# Changement climatique (kg CO2 eq/kg de produit) - Emballage
# Changement climatique (kg CO2 eq/kg de produit) - Transport
# Changement climatique (kg CO2 eq/kg de produit) - Supermarché et distribution
# Changement climatique (kg CO2 eq/kg de produit) - Consommation
# Appauvrissement de la couche d'ozone (E-06 kg CVC11 eq/kg de produit) - Agriculture
# Appauvrissement de la couche d'ozone (E-06 kg CVC11 eq/kg de produit) - Transformation
# Appauvrissement de la couche d'ozone (E-06 kg CVC11 eq/kg de produit) - Emballage
# Appauvrissement de la couche d'ozone (E-06 kg CVC11 eq/kg de produit) - Transport
# Appauvrissement de la couche d'ozone (E-06 kg CVC11 eq/kg de produit) - Supermarché et distribution
# Appauvrissement de la couche d'ozone (E-06 kg CVC11 eq/kg de produit) - Consommation
# Rayonnements ionisants (kBq U-235 eq/kg de produit) - Agriculture
# Rayonnements ionisants (kBq U-235 eq/kg de produit) - Transformation
# Rayonnements ionisants (kBq U-235 eq/kg de produit) - Emballage
# Rayonnements ionisants (kBq U-235 eq/kg de produit) - Transport
# Rayonnements ionisants (kBq U-235 eq/kg de produit) - Supermarché et distribution
# Rayonnements ionisants (kBq U-235 eq/kg de produit) - Consommation
# Formation photochimique d'ozone (E-03 kg NMVOC eq/kg de produ
épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit) - Agriculture
# Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit) - Transformation
# Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit) - Emballage
# Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit) - Transport
# Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit) - Supermarché et distribution
# Épuisement des ressources minéraux (E-06 kg Sb eq/kg de produit) - Consommation
# DQR - P
# DQR - TiR
# DQR - GR
# DQR - TeR

# %%
data_etape.info
# Out:
# <bound method DataFrame.info of      Code AGB  Code CIQUAL                             Groupe d'aliment  \
# 0       12112        12112                    lait et produits laitiers
# 1       13712        13712  fruits, légumes, légumineuses et oléagineux
# 2       13713        13713  fruits, légumes, légumineuses et oléagineux
# 3       13714        13714  fruits, légumes, légumineuses et oléagineux
# 4       13715        13715  fruits, légumes, légumineuses et oléagineux
# ...       ...          ...                                          ...
# 2475    19592        19592                    lait et produits laitiers
# 2476    19593        19593                    lait et produits laitiers
# 2477    19594        19594                    lait et produits laitiers
# 2478    19598        19598                    lait et produits laitiers
# 2479    19599        19599                    lait et produits laitiers
#
#                      Sous-groupe d'aliment  \
# 0                                 fromages
# 1                                   fruits
# 2                                   fruits
# 3                                   fruits
# 4                                   fruits
# ...                                    ...
# 2475  produits laitiers frais et assimilés
# 2476  produits laitiers frais et assimilés
# 2477  produits laitiers frais et assimilés
# 2478  produits laitiers frais et assimilés
# 2479  produits laitiers frais et assimilés
#
#                              Nom du Produit en Français  \
# 0                                             Abondance
# 1            Abricot au sirop léger, appertisé, égoutté
# 2        Abricot au sirop léger, appertisé, non égoutté
# 3                  Abricot au sirop, appertisé, égoutté
# 4              Abricot au sirop, appertisé, non égoutté
# ...                                                 ...
# 2475  Yaourt, lait fermenté ou spécialité laitière, ...
# 2476  Yaourt, lait fermenté ou spécialité laitière, ...
# 2477  Yaourt, lait fermenté ou spécialité laitière, ...
# 2478  Yaourt, lait fermenté ou spécialité laitière, ...
# 2479  Yaourt, lait fermenté ou spécialité laitière, ...
#
#                                                LCI Name   DQR  \
# 0                     Abondance cheese, from cow's milk  2.24
# 1               Apricot, canned in light syrup, drained  2.46
# 2           Apricot, canned in light syrup, not drained  2.46
# 3                    Apricot, in syrup, canned, drained  2.46
# 4                Apricot, in syrup, canned, not drained  2.44
# ...                                                 ...   ...
# 2475  Yogurt, fermented milk or dairy specialty, wit...  3.61
# 2476   Yogurt, fermented milk or dairy specialty, plain  2.04
# 2477  Yogurt, fermented milk or dairy specialty, pla...  2.48
# 2478  Yogurt, fermented milk or dairy specialty, pla...  1.90
# 2479  Yogurt, fermented milk or dairy specialty, pla...  1.90
#
#                                             Nom et code  \
# 0                                     Abondance (12112)
# 1     Abricot au sirop léger, appertisé, égoutté (13...
# 2     Abricot au sirop léger, appertisé, non égoutté...
# 3          Abricot au sirop, appertisé, égoutté (13714)
# 4      Abricot au sirop, appertisé, non égoutté (13715)
# ...                                                 ...
# 2475  Yaourt, lait fermenté ou spécialité laitière, ...
# 2476  Yaourt, lait fermenté ou spécialité laitière, ...
# 2477  Yaourt, lait fermenté ou spécialité laitière, ...
